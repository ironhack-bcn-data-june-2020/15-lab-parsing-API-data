# %% [markdown]
# zalando = json.loads(response)
# zalando# Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
#Offset to 0

'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset=1&sort=popularity'
# Out:
# 'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset=1&sort=popularity'

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize
import urllib.request

# %%
url = 'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset=1&sort=popularity'

# %%
#headers
headers = {'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36'}

# %%
req = requests.get(url, headers=headers)

zalando = urllib.request.urlopen(url)
mybytes = zalando.read()

response = mybytes.decode('utf8')
zalando.close()

# %%
zalando = json.loads(response)
zalando
# Out:
# {'total_count': 175796,
#  'pagination': {'page_count': 892, 'current_page': 1, 'per_page': 84},
#  'sort': 'popularity',
#  'articles': [{'sku': 'TO151H0EB-Q11',
#    'name': 'Cabas - black',
#    'price': {'original': '79,95\xa0€',
#     'promotional': '67,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['One Size'],
#    'url_key': 'tommy-hilfiger-cabas-black-to151h0eb-q11',
#    'media': [{'path': 'TO/15/1H/0E/BQ/11/TO151H0EB-Q11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'TO/15/1H/0E/BQ/11/TO151H0EB-Q11@10.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Tommy Hilfiger',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
# ...

# %%
flat_art = pd.json_normalize(zalando['articles'])
flat_art
# Out:
#               sku                                               name  \
# 0   TO151H0EB-Q11                                      Cabas - black
# 1   NE351B02H-C11                     TECH 9FORTY - Casquette - grey
# 2   ES181I08Q-T11  JASMINE BEACH MID WAIST BRIEF - Bas de bikini ...
# 3   AN621C1J3-I11                           Robe longue - pale mauve
# 4   AN651H08X-D11                                  Pochette - silver
# ..            ...                                                ...
# 79  TA111A1NG-O11                   1-1-28033-24 - Sandales - cognac
# 80  AN611N0AM-O11          LEATHER BOOTIES - Boots à talons - cognac
# 81  RE011S06G-A12      CLUB C 85 - Baskets basses - white/light grey
# 82  LA221C03I-Q11                  DAMEN GÜRTEL - Robe d'été - black
# 83  NI154Q008-Q11                            Casquette - black/black
#
#                                                 sizes  \
# 0                                          [One Size]
# ...

# %%
# Sku as index name
flat_art.set_index('sku', inplace=True)

# %%
# I don't understand how to create the loop FOR for additional pages

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# Trending brand "Anna Field"
flat_art.groupby("brand_name").count().sort_values(by = "name", ascending = False)
# Out:
#                      name  sizes  url_key  media  is_premium  family_articles  \
# brand_name
# Anna Field             27     27       27     27          27               27
# Even&Odd               15     15       15     15          15               15
# Mango                   4      4        4      4           4                4
# Puma                    4      4        4      4           4                4
# Vans                    3      3        3      3           3                3
# Tamaris                 3      3        3      3           3                3
# Levi's®                 3      3        3      3           3                3
# Tommy Hilfiger          2      2        2      2           2                2
# Reebok Classic          2      2        2      2           2                2
# Pier One                2      2        2      2           2                2
# New Era                 2      2        2      2           2                2
# ...

# %%
# About the products with the highest discount, I can see it in "flags", but I don't know how to do it.
