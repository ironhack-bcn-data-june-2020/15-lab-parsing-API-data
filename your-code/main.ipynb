# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here
url = 'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset=84&sort=popularity'

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here

import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'

import urllib.request
from urllib.parse import urlencode, quote_plus

def get_zalando_page_info(offset=84, sort='sale'):
    
    url = 'https://www.zalando.fr/api/catalog/articles/?'
    params = urlencode({'categories':'promo-femme', 'limit': 84, 'offset': offset, 'sort': sort}, quote_via=quote_plus)
    
    print(url + params)
    
    req = urllib.request.Request(
        url + params, 
        data=None, 
        headers={
            'User-Agent': user_agent
        }
    )

    f = urllib.request.urlopen(req)
    return json.loads(f.read().decode('utf-8'))


get_zalando_page_info()
# Out:
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=84&sort=sale
# {'total_count': 180304,
#  'pagination': {'page_count': 892, 'current_page': 2, 'per_page': 84},
#  'sort': 'sale',
#  'articles': [{'sku': 'CO411A0BD-002',
#    'name': 'CHUCK TAYLOR ALL STAR HI - Baskets montantes - white',
#    'price': {'original': '69,95\xa0€',
#     'promotional': '62,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35',
#     '36',
#     '36.5',
#     '37',
#     '37.5',
#     '38',
#     '39',
#     '39.5',
#     '40',
#     '41',
#     '41.5',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '46',
#     '46.5',
#     '48',
#     '49',
#     '50',
#     '51.5',
#     '53',
#     '54'],
#    'url_key': 'converse-baskets-montantes-blanc-co411a0bd-002',
#    'media': [{'path': 'CO/41/1A/0B/D0/02/CO411A0BD-002@123.2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True},
#     {'path': 'CO/41/1A/0B/D0/02/CO411A0BD-002@118.2.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Converse',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'M3111A0NF-A12',
#    'name': 'Baskets basses - white/blue m.',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '17,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '38', '39', '40', '41'],
#    'url_key': 'marco-tozzi-baskets-basses-whiteblue-m3111a0nf-a12',
#    'media': [{'path': 'M3/11/1A/0N/FA/12/M3111A0NF-A12@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Marco Tozzi',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'ON321N17O-Q11',
#    'name': 'ONLDAISY PUSH UP - Jeans Skinny - black denim',
#    'price': {'original': '37,99\xa0€',
#     'promotional': '13,39\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['25x30',
#     '25x32',
#     '26x30',
#     '26x32',
#     '26x34',
#     '27x30',
#     '27x32',
#     '28x30',
#     '28x32',
#     '29x32',
#     '30x30',
#     '31x32',
#     '31x34',
#     '32x30'],
#    'url_key': 'only-onldaisy-push-up-jeans-skinny-black-denim-on321n17o-q11',
#    'media': [{'path': 'ON/32/1N/17/OQ/11/ON321N17O-Q11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'ON/32/1N/17/OQ/11/ON321N17O-Q11@3.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'ONLY',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-65%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'PE321N09A-K11',
#    'name': 'KAMELIA - Jeans Skinny - medium blue denim',
#    'price': {'original': '37,99\xa0€',
#     'promotional': '11,39\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'pieces-kamelia-jeans-skinny-medium-blue-denim-pe321n09a-k11',
#    'media': [{'path': 'PE/32/1N/09/AK/11/PE321N09A-K11@13.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'PE/32/1N/09/AK/11/PE321N09A-K11@12.1.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Pieces',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'ON321N16Y-Q11',
#    'name': 'ONLCARMEN CBL513 - Jeans Skinny - black denim',
#    'price': {'original': '43,99\xa0€',
#     'promotional': '13,39\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['25x30',
#     '26x30',
#     '26x32',
#     '27x30',
#     '27x32',
#     '28x30',
#     '28x32',
#     '28x34',
#     '29x30',
#     '29x32',
#     '29x34',
#     '30x34',
#     '32x30',
#     '32x32'],
#    'url_key': 'only-onlcarmen-cbl513-jeans-skinny-black-denim-on321n16y-q11',
#    'media': [{'path': 'ON/32/1N/16/YQ/11/ON321N16Y-Q11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'ON/32/1N/16/YQ/11/ON321N16Y-Q11@8.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'ONLY',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'VE121E1XB-J11',
#    'name': 'VMKARINA  - Blouse - salute',
#    'price': {'original': '34,99\xa0€',
#     'promotional': '10,49\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'vero-moda-vmkarina-blouse-salute-ve121e1xb-j11',
#    'media': [{'path': 'VE/12/1E/1X/BJ/11/VE121E1XB-J11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'VE/12/1E/1X/BJ/11/VE121E1XB-J11@8.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Vero Moda',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI111A0IL-C12',
#    'name': 'DAYBREAK - Baskets basses - particle grey/summit white/vast grey/vivid purple/laser orange/medium brown',
#    'price': {'original': '89,95\xa0€',
#     'promotional': '35,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['37.5', '38', '38.5', '39', '40', '40.5', '41', '42'],
#    'url_key': 'nike-sportswear-daybreak-baskets-basses-ni111a0il-c12',
#    'media': [{'path': 'NI/11/1A/0I/LC/12/NI111A0IL-C12@14.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': 'HOT DROP',
#      'tracking_value': 'mu_sneaker_releases'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -60%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'FID21G00E-A11',
#    'name': 'TAOTRACK JACKET - Veste de survêtement - lobster bisque/bright white',
#    'price': {'original': '84,95\xa0€',
#     'promotional': '25,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '42'],
#    'url_key': 'fila-petite-taotrack-jacket-veste-de-survetement-lobster-bisquebright-white-fid21g00e-a11',
#    'media': [{'path': 'FI/D2/1G/00/EA/11/FID21G00E-A11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'FI/D2/1G/00/EA/11/FID21G00E-A11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Fila Petite',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'},
#     {'key': 'assortmentArea', 'value': 'Petite', 'tracking_value': 'petite'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AN651Q00Y-B11',
#    'name': 'Sac à dos - tan',
#    'price': {'original': '29,99\xa0€',
#     'promotional': '10,59\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['One Size'],
#    'url_key': 'anna-field-sac-a-dos-tan-an651q00y-b11',
#    'media': [{'path': 'AN/65/1Q/00/YB/11/AN651Q00Y-B11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Anna Field',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-65%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'EV451M020-J11',
#    'name': 'SET - Montre - rose/gold-coloured',
#    'price': {'original': '24,99\xa0€',
#     'promotional': '7,59\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['One Size'],
#    'url_key': 'evenandodd-set-montre-rosegold-coloured-ev451m020-j11',
#    'media': [{'path': 'EV/45/1M/02/0J/11/EV451M020-J11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Even&Odd',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'TA111A20H-M11',
#    'name': 'SLIDES - Tongs - olive',
#    'price': {'original': '43,95\xa0€',
#     'promotional': '13,35\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['37', '38', '39', '40'],
#    'url_key': 'tamaris-tongs-olive-ta111a20h-m11',
#    'media': [{'path': 'TA/11/1A/20/HM/11/TA111A20H-M11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Tamaris',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'MOQ21G01Q-H11',
#    'name': "NOELLE JACKET - Veste d'hiver - orange dark",
#    'price': {'original': '80,00\xa0€',
#     'promotional': '24,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XXS', 'XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'monki-noelle-jacket-veste-dhiver-orange-dark-moq21g01q-h11',
#    'media': [{'path': 'MO/Q2/1G/01/QH/11/MOQ21G01Q-H11@6.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'MO/Q2/1G/01/QH/11/MOQ21G01Q-H11@10.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Monki',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TA111A1RZ-A11',
#    'name': 'Tongs - white',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '17,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['37', '38', '39', '40', '41'],
#    'url_key': 'tamaris-tongs-white-ta111a1rz-a11',
#    'media': [{'path': 'TA/11/1A/1R/ZA/11/TA111A1RZ-A11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Tamaris',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'FID21A00O-A11',
#    'name': 'TAOTRACK PANTS OVERLENGTH PETITE - Pantalon classique - lobster bisque / bright white',
#    'price': {'original': '79,95\xa0€',
#     'promotional': '23,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '40'],
#    'url_key': 'fila-petite-taotrack-pants-overlength-petite-pantalon-classique-lobster-bisque--bright-white-fid21a00o-a11',
#    'media': [{'path': 'FI/D2/1A/00/OA/11/FID21A00O-A11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'FI/D2/1A/00/OA/11/FID21A00O-A11@10.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Fila Petite',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'},
#     {'key': 'assortmentArea', 'value': 'Petite', 'tracking_value': 'petite'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'MEJ21D031-A11',
#    'name': 'LADIES MAGIC MONDAY SLOGAN LONG SLEEVE - T-shirt à manches longues - black',
#    'price': {'original': '24,95\xa0€',
#     'promotional': '8,85\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L', 'XL'],
#    'url_key': 'merchcode-ladies-magic-monday-slogan-long-sleeve-t-shirt-a-manches-longues-black-mej21d031-a11',
#    'media': [{'path': 'ME/J2/1D/03/1A/11/MEJ21D031-A11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'ME/J2/1D/03/1A/11/MEJ21D031-A11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Merchcode',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -65%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TA111A1S0-C11',
#    'name': 'Sandales - pewter',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '17,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['37', '38', '40'],
#    'url_key': 'tamaris-sandales-pewter-ta111a1s0-c11',
#    'media': [{'path': 'TA/11/1A/1S/0C/11/TA111A1S0-C11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Tamaris',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': '1FI54Q002-Q12',
#    'name': 'DAD - Casquette - black iris',
#    'price': {'original': '32,95\xa0€',
#     'promotional': '9,85\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['One Size'],
#    'url_key': 'fila-dad-cap-linear-strap-back-casquette-black-iris-1fi54q002-q12',
#    'media': [{'path': '1F/I5/4Q/00/2Q/12/1FI54Q002-Q12@17.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': '1F/I5/4Q/00/2Q/12/1FI54Q002-Q12@13.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Fila',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'ES111A0L8-Q11',
#    'name': 'LEKY  - Sandales - black',
#    'price': {'original': '59,99\xa0€',
#     'promotional': '17,99\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '38', '39', '40', '41'],
#    'url_key': 'esprit-leky-sandales-es111a0l8-q11',
#    'media': [{'path': 'ES/11/1A/0L/8Q/11/ES111A0L8-Q11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Esprit',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'A0151L0JZ-D11',
#    'name': "CAYNE - Boucles d'oreilles - silver-coloured",
#    'price': {'original': '14,95\xa0€',
#     'promotional': '4,55\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['One Size'],
#    'url_key': 'aldo-cayne-boucles-doreilles-a0151l0jz-d11',
#    'media': [{'path': 'A0/15/1L/0J/ZD/11/A0151L0JZ-D11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'ALDO',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': '1FI51H006-Q11',
#    'name': 'NEW PUSHER BAG BERLIN - Sac bandoulière - black',
#    'price': {'original': '24,95\xa0€',
#     'promotional': '9,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['One Size'],
#    'url_key': 'fila-new-pusher-bag-berlin-sac-bandouliere-1fi51h006-q11',
#    'media': [{'path': '1F/I5/1H/00/6Q/11/1FI51H006-Q11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': '1F/I5/1H/00/6Q/11/1FI51H006-Q11@10.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Fila',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-60%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'M9121A1YH-M11',
#    'name': 'Pantalon classique - groen',
#    'price': {'original': '29,99\xa0€',
#     'promotional': '15,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'mango-linen-pantalon-classique-m9121a1yh-m11',
#    'media': [{'path': 'M9/12/1A/1Y/HM/11/M9121A1YH-M11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Mango',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-47%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TON41D00U-H11',
#    'name': 'PERFORMANCE BOXY - T-shirt imprimé - orange',
#    'price': {'original': '54,95\xa0€',
#     'promotional': '16,75\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'L'],
#    'url_key': 'tommy-sport-performance-boxy-t-shirt-de-sport-ton41d00u-h11',
#    'media': [{'path': 'TO/N4/1D/00/UH/11/TON41D00U-H11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'TO/N4/1D/00/UH/11/TON41D00U-H11@7.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Tommy Sport',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TA111A1SO-F11',
#    'name': 'Ballerines - rose',
#    'price': {'original': '49,95\xa0€',
#     'promotional': '17,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35', '37', '38', '39', '40'],
#    'url_key': 'tamaris-woms-ballerines-ta111a1so-f11',
#    'media': [{'path': 'TA/11/1A/1S/OF/11/TA111A1SO-F11@15.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Tamaris',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -65%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'JY121N058-K11',
#    'name': 'TUBA LIFE GIRLFRIEND CROPPED - Jean boyfriend - medium blue denim',
#    'price': {'original': '29,99\xa0€',
#     'promotional': '11,99\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '42', '44'],
#    'url_key': 'jdy-tuba-life-girlfriend-cropped-jean-boyfriend-medium-blue-denim-jy121n058-k11',
#    'media': [{'path': 'JY/12/1N/05/8K/11/JY121N058-K11@5.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'JDY',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -60%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'CAO21A07J-M11',
#    'name': 'Pantalon classique - dark green',
#    'price': {'original': '29,99\xa0€',
#     'promotional': '11,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['34', '40', '42'],
#    'url_key': 'camaieu-pantalon-classique-dark-green-cao21a07j-m11',
#    'media': [{'path': 'CA/O2/1A/07/JM/11/CAO21A07J-M11@2.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'CA/O2/1A/07/JM/11/CAO21A07J-M11@8.1.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Camaïeu',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-60%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'LE221G02U-K11',
#    'name': 'EX BOYFRIEND TRUCKER - Veste en jean - soft as butter mid',
#    'price': {'original': '109,95\xa0€',
#     'promotional': '65,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L'],
#    'url_key': 'levisr-ex-boyfriend-trucker-veste-en-jean-soft-as-butter-mid-le221g02u-k11',
#    'media': [{'path': 'LE/22/1G/02/UK/11/LE221G02U-K11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LE/22/1G/02/UK/11/LE221G02U-K11@3.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'M9121A1UD-J11',
#    'name': 'ALBERTO - Pantalon classique - fuchsia',
#    'price': {'original': '39,99\xa0€',
#     'promotional': '19,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '40', '42'],
#    'url_key': 'mango-alberto-pantalon-classique-m9121a1ud-j11',
#    'media': [{'path': 'M9/12/1A/1U/DJ/11/M9121A1UD-J11@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Mango',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'LC151H0FA-D11',
#    'name': 'MACAU - Pochette - light silver',
#    'price': {'original': '43,95\xa0€',
#     'promotional': '13,35\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': [],
#    'url_key': 'lcredi-macau-pochette-light-silver-lc151h0fa-d11',
#    'media': [{'path': 'LC/15/1H/0F/AD/11/LC151H0FA-D11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LC/15/1H/0F/AD/11/LC151H0FA-D11@10.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'L.Credi',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'TH354Q007-K11',
#    'name': 'EXTREME BALL - Casquette - meridian blue',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '8,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['One Size'],
#    'url_key': 'the-north-face-extreme-ball-casquette-meridian-blue-th354q007-k11',
#    'media': [{'path': 'TH/35/4Q/00/7K/11/TH354Q007-K11@8.2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'The North Face',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'EV421I0B1-C11',
#    'name': 'V NECK JUMPER - Pullover - grey',
#    'price': {'original': '43,99\xa0€',
#     'promotional': '13,39\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L'],
#    'url_key': 'evenandodd-v-neck-jumper-pullover-ev421i0b1-c11',
#    'media': [{'path': 'EV/42/1I/0B/1C/11/EV421I0B1-C11@4.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'EV/42/1I/0B/1C/11/EV421I0B1-C11@8.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Even&Odd',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'M9121A1TH-A11',
#    'name': 'BOREAL6 - Pantalon de costume - weiß',
#    'price': {'original': '39,99\xa0€',
#     'promotional': '19,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '40', '42', '44', '46'],
#    'url_key': 'mango-boreal6-pantalon-classique-m9121a1th-a11',
#    'media': [{'path': 'M9/12/1A/1T/HA/11/M9121A1TH-A11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Mango',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'VE121E1W1-Q11',
#    'name': 'VMLUCIA - Chemisier - black',
#    'price': {'original': '29,99\xa0€',
#     'promotional': '9,09\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M'],
#    'url_key': 'vero-moda-vmlucia-blouse-ve121e1w1-q11',
#    'media': [{'path': 'VE/12/1E/1W/1Q/11/VE121E1W1-Q11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'VE/12/1E/1W/1Q/11/VE121E1W1-Q11@10.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Vero Moda',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'ON321E1RZ-K11',
#    'name': 'ONLGRACE BALLOON  - Blouse - cloud dancer/green',
#    'price': {'original': '29,99\xa0€',
#     'promotional': '9,09\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['34', '36', '38'],
#    'url_key': 'only-onlgrace-balloon-t-shirt-a-manches-longues-cloud-dancergreen-on321e1rz-k11',
#    'media': [{'path': 'ON/32/1E/1R/ZK/11/ON321E1RZ-K11@4.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'ON/32/1E/1R/ZK/11/ON321E1RZ-K11@10.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'ONLY',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'VE121A0V0-K11',
#    'name': 'VMJENNANAEVA LOOSE PAPERBAG PANT - Pantalon classique - placid blue/snow white',
#    'price': {'original': '54,99\xa0€',
#     'promotional': '16,49\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '40', '42', '44', '46'],
#    'url_key': 'vero-moda-vmjennanaeva-loose-paperbag-pant-pantalon-classique-placid-bluesnow-white-ve121a0v0-k11',
#    'media': [{'path': 'VE/12/1A/0V/0K/11/VE121A0V0-K11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'VE/12/1A/0V/0K/11/VE121A0V0-K11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Vero Moda',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'V1021C1XW-K11',
#    'name': 'VIAKVARALLA V-NECK MIDI DRESS - Robe chemise - pale mauve/blue/yellow',
#    'price': {'original': '54,99\xa0€',
#     'promotional': '16,69\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['38', '40', '42', '44'],
#    'url_key': 'vila-viakvaralla-midi-dress-robe-dete-pale-mauveblueyellow-v1021c1xw-k11',
#    'media': [{'path': 'V1/02/1C/1X/WK/11/V1021C1XW-K11@16.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'V1/02/1C/1X/WK/11/V1021C1XW-K11@13.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Vila',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'VA215O04A-J11',
#    'name': 'ERA - Baskets basses - fuschia purple/multi/true white',
#    'price': {'original': '79,95\xa0€',
#     'promotional': '23,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['34.5',
#     '35',
#     '36',
#     '36.5',
#     '37',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44.5'],
#    'url_key': 'vans-era-baskets-basses-va215o04a-j11',
#    'media': [{'path': 'VA/21/5O/04/AJ/11/VA215O04A-J11@11.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Vans',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NL011N0BL-Q11',
#    'name': 'CIVIL - Boots à talons - black',
#    'price': {'original': '34,99\xa0€',
#     'promotional': '12,39\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '38', '40'],
#    'url_key': 'new-look-civil-bottines-a-plateau-black-nl011n0bl-q11',
#    'media': [{'path': 'NL/01/1N/0B/LQ/11/NL011N0BL-Q11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'New Look',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-65%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'RE011A0CF-A11',
#    'name': 'COURT DOUBLE MIX - Baskets basses - chalk/night navy/sun glow',
#    'price': {'original': '89,95\xa0€',
#     'promotional': '35,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5',
#     '36',
#     '37',
#     '37.5',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41'],
#    'url_key': 'reebok-classic-court-double-mix-baskets-basses-chalknight-navysun-glow-re011a0cf-a11',
#    'media': [{'path': 'RE/01/1A/0C/FA/11/RE011A0CF-A11@29.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Reebok Classic',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': 'HOT DROP',
#      'tracking_value': 'mu_sneaker_releases'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -60%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'DOB11A04Q-O11',
#    'name': 'WIDE FIT TUBULAR  - Sandales - rust',
#    'price': {'original': '23,99\xa0€',
#     'promotional': '7,29\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['37', '38', '39'],
#    'url_key': 'dorothy-perkins-wide-fit-wide-fit-tubular-sandales-dob11a04q-o11',
#    'media': [{'path': 'DO/B1/1A/04/QO/11/DOB11A04Q-O11@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Dorothy Perkins Wide Fit',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'},
#     {'key': 'shoeWidth', 'value': 'Larges', 'tracking_value': 'wide shoes'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'M9121A1UD-N11',
#    'name': 'ALBERTO - Pantalon classique - khaki',
#    'price': {'original': '39,99\xa0€',
#     'promotional': '19,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '40', '42', '44'],
#    'url_key': 'mango-alberto-pantalon-classique-m9121a1ud-n11',
#    'media': [{'path': 'M9/12/1A/1U/DN/11/M9121A1UD-N11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Mango',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'EV411N094-Q11',
#    'name': 'Boots à talons - black',
#    'price': {'original': '44,99\xa0€',
#     'promotional': '13,69\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '39', '40', '41', '42'],
#    'url_key': 'evenandodd-boots-a-talons-black-ev411n094-q11',
#    'media': [{'path': 'EV/41/1N/09/4Q/11/EV411N094-Q11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Even&Odd',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'VA211A09P-D11',
#    'name': 'CLASSIC UNISEX - Mocassins - silver/true white',
#    'price': {'original': '69,95\xa0€',
#     'promotional': '34,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['34.5',
#     '35',
#     '36',
#     '36.5',
#     '37',
#     '38',
#     '39',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '46',
#     '47'],
#    'url_key': 'vans-classic-baskets-basses-silvertrue-white-va211a09p-d11',
#    'media': [{'path': 'VA/21/1A/09/PD/11/VA211A09P-D11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Vans',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NEG21I00M-A11',
#    'name': 'SPARKLING DREAM KNIT - Pullover - white',
#    'price': {'original': '39,95\xa0€',
#     'promotional': '11,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'XL'],
#    'url_key': 'nly-by-nelly-sparkling-dream-knit-pullover-white-neg21i00m-a11',
#    'media': [{'path': 'NE/G2/1I/00/MA/11/NEG21I00M-A11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'NE/G2/1I/00/MA/11/NEG21I00M-A11@10.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nly by Nelly',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'Y0121E0MR-Q11',
#    'name': 'SINGLET - Blouse - black',
#    'price': {'original': '39,99\xa0€',
#     'promotional': '11,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M'],
#    'url_key': 'yas-singlet-blouse-black-y0121e0mr-q11',
#    'media': [{'path': 'Y0/12/1E/0M/RQ/11/Y0121E0MR-Q11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'YAS',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'SO211A0JL-K11',
#    'name': 'Tongs - navy',
#    'price': {'original': '24,99\xa0€',
#     'promotional': '7,59\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['38', '39', '40', '41', '42'],
#    'url_key': 'soliver-tongs-navy-so211a0jl-k11',
#    'media': [{'path': 'SO/21/1A/0J/LK/11/SO211A0JL-K11@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 's.Oliver',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'A0H15O02B-A11',
#    'name': 'GEL-KAYANO 5 OG - Baskets basses - white',
#    'price': {'original': '139,95\xa0€',
#     'promotional': '41,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['41.5',
#     '42.5',
#     '43.5',
#     '44',
#     '44.5',
#     '45',
#     '46',
#     '46.5',
#     '47',
#     '48',
#     '49'],
#    'url_key': 'asics-tiger-gel-kayano-baskets-basses-a0h15o02b-a11',
#    'media': [{'path': 'A0/H1/5O/02/BA/11/A0H15O02B-A11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'ASICS SportStyle',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'M3111A0QK-K11',
#    'name': 'Ballerines - monarch blue',
#    'price': {'original': '49,95\xa0€',
#     'promotional': '14,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '38', '39', '40'],
#    'url_key': 'marco-tozzi-ballerines-monarch-blue-m3111a0qk-k11',
#    'media': [{'path': 'M3/11/1A/0Q/KK/11/M3111A0QK-K11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Marco Tozzi',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'SO211A0GV-Q11',
#    'name': 'LACE-UP - Baskets basses - black',
#    'price': {'original': '29,99\xa0€',
#     'promotional': '9,09\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '38', '39', '40', '41'],
#    'url_key': 'soliver-lace-up-baskets-basses-black-so211a0gv-q11',
#    'media': [{'path': 'SO/21/1A/0G/VQ/11/SO211A0GV-Q11@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 's.Oliver',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI111A0GI-A13',
#    'name': 'AIR MAX 200 - Baskets basses - white/metallic gold/black/metallic silver',
#    'price': {'original': '124,95\xa0€',
#     'promotional': '55,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36', '36.5', '37.5', '38.5', '40.5'],
#    'url_key': 'nike-sportswear-air-max-200-baskets-basses-ni111a0gi-a13',
#    'media': [{'path': 'NI/11/1A/0G/IA/13/NI111A0GI-A13@15.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -55%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'PY021A02L-Q11',
#    'name': 'CHECK PAPERBAG TROUSER - Pantalon classique - black',
#    'price': {'original': '48,99\xa0€',
#     'promotional': '14,89\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['32', '34', '36', '38'],
#    'url_key': 'miss-selfridge-petite-check-paperbag-trouser-pantalon-classique-black-py021a02l-q11',
#    'media': [{'path': 'PY/02/1A/02/LQ/11/PY021A02L-Q11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'PY/02/1A/02/LQ/11/PY021A02L-Q11@11.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Miss Selfridge Petite',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'},
#     {'key': 'assortmentArea', 'value': 'Petite', 'tracking_value': 'petite'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'ON321C1KY-Q11',
#    'name': "ONLCHICA DRESS - Robe d'été - black",
#    'price': {'original': '39,99\xa0€',
#     'promotional': '11,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '40'],
#    'url_key': 'only-onlchica-dress-robe-dete-black-on321c1ky-q11',
#    'media': [{'path': 'ON/32/1C/1K/YQ/11/ON321C1KY-Q11@6.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'ON/32/1C/1K/YQ/11/ON321C1KY-Q11@8.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'ONLY',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'A0151H0JT-D11',
#    'name': 'DUSSOLLIER - Pochette - silver',
#    'price': {'original': '48,95\xa0€',
#     'promotional': '14,85\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['One Size'],
#    'url_key': 'aldo-dussollier-pochette-silver-a0151h0jt-d11',
#    'media': [{'path': 'A0/15/1H/0J/TD/11/A0151H0JT-D11@6.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'ALDO',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'BU311A0AT-B11',
#    'name': 'JULIA - Sandales - tan',
#    'price': {'original': '64,99\xa0€',
#     'promotional': '19,49\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '38', '39'],
#    'url_key': 'buffalo-julia-sandales-tan-bu311a0at-b11',
#    'media': [{'path': 'BU/31/1A/0A/TB/11/BU311A0AT-B11@5.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Buffalo',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'TA111A1NG-O11',
#    'name': '1-1-28033-24 - Sandales - cognac',
#    'price': {'original': '69,95\xa0€',
#     'promotional': '20,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '38', '39', '40', '41'],
#    'url_key': 'tamaris-sandales-cognac-ta111a1ng-o11',
#    'media': [{'path': 'TA/11/1A/1N/GO/11/TA111A1NG-O11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Tamaris',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -70%',
# ...
#     {'key': 'crocheted', 'label': 'Crocheté'},
#     {'key': 'leather', 'label': 'Cuir'},
#     {'key': 'cord', 'label': 'Côtelé'},
#     {'key': 'denim', 'label': 'Denim'},
#     {'key': 'lace', 'label': 'Dentelle'},
#     {'key': 'felt', 'label': 'Feutre'},
#     {'key': 'flanelette', 'label': 'Flanelle chaude'},
#     {'key': 'hardshell', 'label': 'Hardshell'},
#     {'key': 'imitation_leather', 'label': 'Imitation cuir'},
#     {'key': 'jersey', 'label': 'Jersey'},
#     {'key': 'wool', 'label': 'Laine'},
#     {'key': 'linen', 'label': 'Lin'},
#     {'key': 'pure_lyocell', 'label': 'lyocell (100%)'},
#     {'key': 'mesh', 'label': 'Mesh'},
#     {'key': 'chiffon', 'label': 'mousseline'},
#     {'key': 'sequins', 'label': 'paillettes'},
#     {'key': 'feathers', 'label': 'Plume'},
#     {'key': 'fleece', 'label': 'Polaire'},
#     {'key': 'polyester', 'label': 'Polyester'},
#     {'key': 'satin', 'label': 'Satin'},
#     {'key': 'softshell', 'label': 'Softshell'},
#     {'key': 'silk', 'label': 'Soie'},
#     {'key': 'rib', 'label': 'Strié'},
#     {'key': 'sweat', 'label': 'Sweat'},
#     {'key': 'synthetic', 'label': 'Synthétique'},
#     {'key': 'textile', 'label': 'Textile'},
#     {'key': 'braided', 'label': 'tressé'},
#     {'key': 'knitted_fabric', 'label': 'tricots'},
#     {'key': 'varnish', 'label': 'Verni'},
#     {'key': 'viscose', 'label': 'Viscose'}]},
#   {'key': 'sustainable',
#    'label': 'Éco-responsabilité',
#    'url_key': 'sustainable',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Éco-responsabilité'}],
#    'group_id': 'sustainable',
#    'description': 'Du commerce équitable au respect de l’environnement : bienvenue dans notre gamme de produits durables.'},
#   {'key': 'patterns',
#    'label': 'Motif',
#    'url_key': 'pattern',
#    'kind': 'values',
#    'values': [{'key': 'camouflage', 'label': 'camouflage'},
#     {'key': 'checked', 'label': 'carreaux'},
#     {'key': 'herring_bone', 'label': 'chevrons'},
#     {'key': 'flecked', 'label': 'chiné'},
#     {'key': 'plain', 'label': 'couleur unie'},
#     {'key': 'gradient', 'label': 'dégradé'},
#     {'key': 'burnout', 'label': 'dévoré'},
#     {'key': 'pinstripe', 'label': 'fines rayures'},
#     {'key': 'floral', 'label': 'floral'},
#     {'key': 'print', 'label': 'imprimé'},
#     {'key': 'animal_print', 'label': 'imprimé animal'},
#     {'key': 'leopard', 'label': 'imprimé léopard'},
#     {'key': 'photo_print', 'label': 'imprimé photo'},
#     {'key': 'colored', 'label': 'multicolore'},
#     {'key': 'paisley', 'label': 'Paisley/cachemire'},
#     {'key': 'striped', 'label': 'rayures'},
#     {'key': 'polka_dot', 'label': 'à pois'}]},
#   {'key': 'occasions',
#    'label': 'Occasion',
#    'url_key': 'occasion',
#    'kind': 'values',
#    'values': [{'key': 'evening_ball', 'label': 'bal de soirée'},
#     {'key': 'business', 'label': 'business'},
#     {'key': 'cocktail_party', 'label': 'cocktail'},
#     {'key': 'lounge_wear', 'label': 'confort/maison'},
#     {'key': 'formal_event', 'label': 'Festif'},
#     {'key': 'oktoberfest', 'label': 'festival de la bière'},
#     {'key': 'bridal', 'label': 'Looks de mariée'},
#     {'key': 'wedding', 'label': 'mariage'},
#     {'key': 'prom', 'label': 'remise des diplômes'},
#     {'key': 'party', 'label': 'soirée'}]},
#   {'key': 'assortment_areas',
#    'label': 'Coupes',
#    'url_key': 'assortment_area',
#    'kind': 'values',
#    'values': [{'key': 'STANDARD', 'label': 'Standard'},
#     {'key': 'MATERNITY', 'label': 'Maternité'},
#     {'key': 'PLUS_SIZE', 'label': 'Grandes tailles'},
#     {'key': 'PETITE', 'label': 'Petite'},
#     {'key': 'TALL', 'label': 'Grande'}]},
#   {'key': 'seasons',
#    'label': 'Saison',
#    'url_key': 'season_name',
#    'kind': 'values',
#    'values': [{'key': 'SUMMER', 'label': 'Printemps/Été'},
#     {'key': 'WINTER', 'label': 'Automne/Hiver'}]},
#   {'key': 'styles',
#    'label': 'Style',
#    'url_key': 'style',
#    'kind': 'values',
#    'values': [{'key': 'casual', 'label': 'casual'},
#     {'key': 'boho_dress', 'label': 'robe bohème'},
#     {'key': 'vintage_dress', 'label': 'robe vintage'},
#     {'key': 'elegant_dress', 'label': 'robe élégante'},
#     {'key': 'sporty', 'label': 'sportif'},
#     {'key': 'urban', 'label': 'Urbain'}]},
#   {'key': 'campaigns',
#    'label': 'Sélections',
#    'url_key': 'camp',
#    'kind': 'values',
#    'values': [{'key': 'mu_sneaker_releases', 'label': 'Hot Sneaker Drops'}]},
#   {'key': 'vegan',
#    'label': 'Végane',
#    'url_key': 'vegan',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Végane'}],
#    'group_id': 'vegan'},
#   {'key': 'shipped_by_zalando',
#    'label': 'Expédié par Zalando',
#    'url_key': 'shipped_by_zalando',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Expédié par Zalando'}],
#    'group_id': 'delivery'},
#   {'key': 'fr_delivery_24h',
#    'label': 'Livraison 24H',
#    'url_key': 'livraison-24h',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Livraison 24H'}],
#    'group_id': 'delivery'}],
#  'total_article_count': 180307,
#  'plusStatus': 'non-eligible',
#  'categoryTree': [{'label': 'Soldes',
#    'id': '8803',
#    'url_key': 'promo-femme',
#    'has_skus': True,
#    'selected': True,
#    'has_children': True,
#    'full_url': '/promo-femme/?order=sale',
#    'children': [{'label': 'Vêtements',
#      'id': '8838',
#      'url_key': 'promo-mode-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-mode-femme/?order=sale',
#      'children': [],
#      'article_count': 125479},
#     {'label': 'Chaussures',
#      'id': '8804',
#      'url_key': 'promo-chaussures-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-chaussures-femme/?order=sale',
#      'children': [],
#      'article_count': 39531},
#     {'label': 'Sacs et accessoires',
#      'id': '8860',
#      'url_key': 'promo-accessoires-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-accessoires-femme/?order=sale',
#      'children': [],
#      'article_count': 13584},
#     {'label': 'Lingerie',
#      'id': '8850',
#      'url_key': 'promo-lingerie-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-lingerie-femme/?order=sale',
#      'children': [],
#      'article_count': 5827},
#     {'label': 'Luxe',
#      'id': '13429',
#      'url_key': 'promo-luxe-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-luxe-femme/?order=sale',
#      'children': [],
#      'article_count': 10121},
#     {'label': 'Sport',
#      'id': '13286',
#      'url_key': 'promo-sport-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-sport-femme/?order=sale',
#      'children': [],
#      'article_count': 10038},
#     {'label': 'Beauté',
#      'id': '13478',
#      'url_key': 'beaute-femme-promo',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/beaute-femme-promo/?order=sale',
#      'children': [],
#      'article_count': 1202}],
#    'article_count': 180309}],
#  'sortingKeys': [{'type': 'popularity', 'dir': 'desc', 'label': 'Préférés'},
#   {'type': 'activation_date', 'dir': 'desc', 'label': 'Nouveautés'},
#   {'type': 'price_asc', 'dir': 'asc', 'label': 'Prix croissant'},
#   {'type': 'price_desc', 'dir': 'desc', 'label': 'Prix décroissant'},
#   {'type': 'sale', 'dir': 'desc', 'label': 'Soldes'}],
#  'breadcrumbs': [{'items': [{'label': 'Femme',
#      'url_key': 'femme',
#      'full_url': '/femme/?order=sale'},
#     {'label': 'Soldes',
#      'url_key': 'promo-femme',
#      'full_url': '/promo-femme/?order=sale'}]}],
#  'querySemantics': {'positive_filters': [{'key': 'categories',
#     'url_key': 'category',
#     'kind': 'values',
#     'values': [{'key': 'promo-femme',
#       'url_key': 'promo-femme',
#       'label': 'Soldes',
#       'seo_label': 'Soldes femme',
#       'reset_url': '/?order=sale',
#       'id': '8803'}]}],
#   'negative_filters': [],
#   'reset_query_url': '/promo-femme/?order=sale',
#   'reset_url': '/promo-femme/?order=sale',
#   'app_url': '?urlKey=promo-femme&order=sale&appdomainId=11'},
#  'articlesToShow': 84,
#  'octopusTests': [],
#  'locale': 'fr-FR',
#  'isLoggedIn': False,
#  'notification': None,
#  'resetFilters': {'categories': [{'key': 'promo-femme',
#     'url_key': 'promo-femme',
#     'label': 'Soldes',
#     'seo_label': 'Soldes femme',
#     'reset_url': '/?order=sale',
#     'id': '8803'}]},
#  'selectedFilters': {'categories': ['promo-femme']},
#  'ssrArticleCount': 32,
#  'feedbackId': '5c112594708a306b9e611805',
#  'variants': {'fullWidthCatalog': False,
#   'premiumCatalog': False,
#   'myBrandsFilter': True,
#   'hideCategories': False,
#   'mobileLightFilters': True,
#   'truncatedCount': False,
#   'topTeaserPlaceholder': True,
#   'salesBannerCountdown': False,
#   'lazyArticleImages': False,
#   'useImg01': True},
#  'contentPositions': {'in-cat-carousel': 9,
#   'in-cat-carousel-mobile': 6,
#   'in-cat-carousel-fullwidth': 8,
#   'in-cat-teaser': 9,
#   'upper-in-cat-teaser': 5,
#   'entry-point-teasers': [7, 14, 20, 26],
#   'in-grid-filter': 4,
#   'search-dialog-mobile': [14],
#   'search-dialog-mobile-premium': [10],
#   'search-dialog-fullwidth': [24],
#   'search-dialog-premium': [16],
#   'search-dialog': [18],
#   'size-dialog': 12,
#   'sneaker-carousel': [12],
#   'outfits': [5, 14, 23],
#   'outfits-mobile': [5, 11, 17, 23],
#   'outfits-fullwidth': [7, 19, 31, 43],
#   'style-profile-follow-brands-banner': 6,
#   'style-profile-follow-brands-banner-mobile': 4,
#   'ingrid-teaser': 6,
#   'ingrid-premium-teaser': 5,
#   'ingrid-mobile-teaser': 4,
#   'ingrid-premium-mobile-teaser': 3},
#  'prideEnabled': False,
#  'lazyArticleImages': False,
#  'hideSearchTerm': False,
#  'iconPaths': {'filters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'mobileFilters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'flags': {'slow_delivery_flag': 'icons/clock.svg',
#    'fast_delivery_flag': 'icons/truck-fast-orange-3.svg',
#    'plus_delivery_flag': 'icons/plus-short-1.svg',
#    'zalando_plus': 'icons/zalando-plus.svg'}},
#  'teaser': {'content': {'creative_format': 'TEASER',
#    'brand': {'name': 'non-fashion brand', 'code': '-1'},
#    'pixels': ['https://crow.zalando.de/impressions/8924da7f-0e53-4d0e-a4f6-ec551c601e63/702cfae1-a2d1-485e-8d27-1dcd71016c79/creative.png?slotId=21672e65-4b93-4cd0-9943-404c19eece9a&creativeId=fd084906-fda9-443b-9f9e-dd61ad85fd18&timeUnit=null&timeUnitCount=null&uuid=803b2b82-b07f-4009-a708-1141d1542b79&bid=null&requestId=c78538fe-1413-43af-a8d3-b52e3825ceb1&adLocation=catalog&frontendType=browser&s=3F1591F683CDB95493453BD2D5644D49'],
#    'images': [{'aspect_ratio': None,
#      'max_screen_size': 1200,
#      'image_url': 'https://mosaic03.ztat.net/vgs/media/cropbyfocalarea/1600/299/3200/549/3500/spp-media-p1/c5c39f23371f4307b58061c1fcba8da9/b9fa5875d165441aaecdb9092c3f40dd.jpg',
#      'image_width': None},
#     {'aspect_ratio': None,
#      'max_screen_size': 600,
#      'image_url': 'https://mosaic03.ztat.net/vgs/media/cropbyfocalarea/480/231/960/462/2229/spp-media-p1/b61a933683b54966a88cf00f0dfbab32/5c80598840ff45faa028e447e2588f00.jpg',
#      'image_width': None}],
#    'creative_id': 'fd084906-fda9-443b-9f9e-dd61ad85fd18',
#    'campaign_id': '8924da7f-0e53-4d0e-a4f6-ec551c601e63',
#    'campaign_name': 'CAMS_CAMS_-_CW21_SS20_MSC_EoSS_SalesBanner_Wave4_Regular_All_FR_C_000000',
#    'campaign_source_id': 'NE2RZQEoQWu',
#    'text_fields': {'cta': "J'en profite\t\t\t\t",
#     'bg_color': '#940000',
#     'legal_claim': "*Les soldes d'été se terminent le 11/08/2020 à 23h59. Offre valable sur une sélection d'articles et dans la limite des stocks disponibles.\t",
#     'title': "SOLDES JUSQU'À -70% *\t\t",
#     'type': 'sales',
#     'sales_template': 'Discount',
#     'byline': "C'est bientôt la fin!\t\t",
#     'foreground_text_color': '#FFFFFF'},
#    'tracking_events': {'impression': {'type': 'advertising-event',
#      'advertising-category': 'category',
#      'advertising-action': 'teaser impression',
#      'advertising-parameter': {'channel_name': 'CF',
#       'campaign_name': 'CAMS_CAMS_-_CW21_SS20_MSC_EoSS_SalesBanner_Wave4_Regular_All_FR_C_000000',
#       'brand_code': '-1',
#       'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#       'flow_id': '7S4fuQti5Rjx93XR',
#       'shop_slot_id': 'catalog',
#       'campaign_source_id': 'NE2RZQEoQWu',
#       'request_id': 'c78538fe-1413-43af-a8d3-b52e3825ceb1',
#       'campaign_id': '8924da7f-0e53-4d0e-a4f6-ec551c601e63',
#       'creative_id': 'fd084906-fda9-443b-9f9e-dd61ad85fd18'}},
#     'view': {'type': 'teaser view',
#      'category': 'category',
#      'label': 'catalog.teaser',
#      'id': 'NE2RZQEoQWu',
#      'name': "SOLDES JUSQU'À -70% *\t\t",
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'campaign_name': 'CAMS_CAMS_-_CW21_SS20_MSC_EoSS_SalesBanner_Wave4_Regular_All_FR_C_000000',
#        'brand_code': '-1',
#        'adId': '4lwHsEODTtq',
#        'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#        'flow_id': '7S4fuQti5Rjx93XR',
#        'shop_slot_id': 'catalog',
#        'campaign_source_id': 'NE2RZQEoQWu',
#        'request_id': 'c78538fe-1413-43af-a8d3-b52e3825ceb1',
#        'campaign_id': '8924da7f-0e53-4d0e-a4f6-ec551c601e63',
#        'creative_id': 'fd084906-fda9-443b-9f9e-dd61ad85fd18'},
#       'dimension74': {'adId': '4lwHsEODTtq'}}},
#     'click': {'type': 'teaser click',
#      'category': 'category',
#      'label': 'catalog.teaser',
#      'id': 'NE2RZQEoQWu',
#      'name': "SOLDES JUSQU'À -70% *\t\t",
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'campaign_name': 'CAMS_CAMS_-_CW21_SS20_MSC_EoSS_SalesBanner_Wave4_Regular_All_FR_C_000000',
#        'brand_code': '-1',
#        'adId': '4lwHsEODTtq',
#        'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#        'flow_id': '7S4fuQti5Rjx93XR',
#        'shop_slot_id': 'catalog',
#        'campaign_source_id': 'NE2RZQEoQWu',
#        'request_id': 'c78538fe-1413-43af-a8d3-b52e3825ceb1',
#        'campaign_id': '8924da7f-0e53-4d0e-a4f6-ec551c601e63',
#        'creative_id': 'fd084906-fda9-443b-9f9e-dd61ad85fd18'},
#       'dimension74': {'adId': '4lwHsEODTtq'}}}},
#    'view_pixels': ['https://crow.zalando.de/views/8924da7f-0e53-4d0e-a4f6-ec551c601e63/702cfae1-a2d1-485e-8d27-1dcd71016c79/creative.png?slotId=21672e65-4b93-4cd0-9943-404c19eece9a&creativeId=fd084906-fda9-443b-9f9e-dd61ad85fd18&timeUnit=null&timeUnitCount=null&uuid=589be48a-703e-497b-b6a1-a03c75b0fca1&bid=null&requestId=c78538fe-1413-43af-a8d3-b52e3825ceb1&adLocation=catalog&frontendType=browser&s=DEAFCB0312EBDD59C9CBCC93400F8A19'],
#    'tracking_data': {'explicit_tracking_params': {'flow_id': '7S4fuQti5Rjx93XR',
#      'entity_id': None,
#      'shop_slot_id': 'catalog',
#      'brand_code': '-1',
#      'campaign_source_id': 'NE2RZQEoQWu',
#      'campaign_id': '8924da7f-0e53-4d0e-a4f6-ec551c601e63',
#      'creative_id': 'fd084906-fda9-443b-9f9e-dd61ad85fd18',
#      'campaign_name': 'CAMS_CAMS_-_CW21_SS20_MSC_EoSS_SalesBanner_Wave4_Regular_All_FR_C_000000',
#      'target_entity_id': None},
#     'cf_tracking_params': {'channel_name': 'CF',
#      'campaign_name': 'CAMS_CAMS_-_CW21_SS20_MSC_EoSS_SalesBanner_Wave4_Regular_All_FR_C_000000',
#      'brand_code': '-1',
#      'adId': '4lwHsEODTtq',
#      'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#      'flow_id': '7S4fuQti5Rjx93XR',
#      'shop_slot_id': 'catalog',
#      'campaign_source_id': 'NE2RZQEoQWu',
#      'request_id': 'c78538fe-1413-43af-a8d3-b52e3825ceb1',
#      'campaign_id': '8924da7f-0e53-4d0e-a4f6-ec551c601e63',
#      'creative_id': 'fd084906-fda9-443b-9f9e-dd61ad85fd18'}},
#    'click_url': 'https://www.zalando.fr/promo-femme/&Sale=True'},
#   'channel_name': 'CF',
#   'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a'},
#  'inCatalogTeaser': None,
#  'entryPointTeasers': None,
#  'upperInCatTeaser': None,
#  'collection': None,
#  'carouselTeaser': None,
#  'wishlist': None,
#  'pills': None,
#  'sizeOnboardingDialog': None}

# %%
response = get_zalando_page_info()
total_pages = response['pagination']['page_count']

total_pages
# Your code

frames = []


for page in range(2, total_pages+1):
    
    response = get_zalando_page_info(page*84)
    articles = pd.json_normalize(response['articles'])
    frames.append(articles)

data_set = pd.concat(frames)

data_set.set_index('sku', inplace=True)

data_set
# Out:
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=84&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=168&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=252&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=336&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=420&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=504&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=588&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=672&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=756&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=840&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=924&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=1008&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=1092&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=1176&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=1260&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=1344&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=1428&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=1512&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=1596&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=1680&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=1764&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=1848&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=1932&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=2016&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=2100&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=2184&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=2268&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=2352&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=2436&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=2520&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=2604&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=2688&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=2772&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=2856&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=2940&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=3024&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=3108&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=3192&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=3276&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=3360&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=3444&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=3528&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=3612&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=3696&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=3780&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=3864&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=3948&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=4032&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=4116&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=4200&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=4284&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=4368&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=4452&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=4536&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=4620&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=4704&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=4788&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=4872&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=4956&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=5040&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=5124&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=5208&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=5292&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=5376&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=5460&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=5544&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=5628&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=5712&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=5796&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=5880&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=5964&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=6048&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=6132&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=6216&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=6300&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=6384&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=6468&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=6552&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=6636&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=6720&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=6804&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=6888&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=6972&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=7056&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=7140&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=7224&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=7308&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=7392&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=7476&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=7560&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=7644&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=7728&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=7812&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=7896&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=7980&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=8064&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=8148&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=8232&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=8316&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=8400&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=8484&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=8568&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=8652&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=8736&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=8820&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=8904&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=8988&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=9072&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=9156&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=9240&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=9324&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=9408&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=9492&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=9576&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=9660&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=9744&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=9828&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=9912&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=9996&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=10080&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=10164&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=10248&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=10332&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=10416&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=10500&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=10584&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=10668&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=10752&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=10836&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=10920&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=11004&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=11088&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=11172&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=11256&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=11340&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=11424&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=11508&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=11592&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=11676&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=11760&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=11844&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=11928&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=12012&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=12096&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=12180&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=12264&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=12348&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=12432&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=12516&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=12600&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=12684&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=12768&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=12852&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=12936&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=13020&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=13104&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=13188&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=13272&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=13356&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=13440&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=13524&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=13608&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=13692&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=13776&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=13860&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=13944&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=14028&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=14112&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=14196&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=14280&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=14364&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=14448&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=14532&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=14616&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=14700&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=14784&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=14868&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=14952&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=15036&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=15120&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=15204&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=15288&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=15372&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=15456&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=15540&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=15624&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=15708&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=15792&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=15876&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=15960&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=16044&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=16128&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=16212&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=16296&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=16380&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=16464&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=16548&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=16632&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=16716&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=16800&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=16884&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=16968&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=17052&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=17136&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=17220&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=17304&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=17388&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=17472&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=17556&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=17640&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=17724&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=17808&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=17892&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=17976&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=18060&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=18144&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=18228&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=18312&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=18396&sort=sale
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-af891af404a5> in <module>
#      10 for page in range(2, total_pages+1):
#      11
# ---> 12     response = get_zalando_page_info(page*84)
#      13     articles = pd.json_normalize(response['articles'])
#      14     frames.append(articles)
#
# <ipython-input-9-4dc2bafbe633> in get_zalando_page_info(offset, sort)
#      19     )
#      20
# ---> 21     f = urllib.request.urlopen(req)
#      22     return json.loads(f.read().decode('utf-8'))
#      23
#
# /usr/local/opt/python@3.8/Frameworks/Python.framework/Versions/3.8/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /usr/local/opt/python@3.8/Frameworks/Python.framework/Versions/3.8/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# /usr/local/opt/python@3.8/Frameworks/Python.framework/Versions/3.8/lib/python3.8/urllib/request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# /usr/local/opt/python@3.8/Frameworks/Python.framework/Versions/3.8/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# /usr/local/opt/python@3.8/Frameworks/Python.framework/Versions/3.8/lib/python3.8/urllib/request.py in https_open(self, req)
#    1391
#    1392         def https_open(self, req):
# -> 1393             return self.do_open(http.client.HTTPSConnection, req,
#    1394                 context=self._context, check_hostname=self._check_hostname)
#    1395
#
# /usr/local/opt/python@3.8/Frameworks/Python.framework/Versions/3.8/lib/python3.8/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1348         try:
#    1349             try:
# -> 1350                 h.request(req.get_method(), req.selector, req.data, headers,
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#    1352             except OSError as err: # timeout error
#
# /usr/local/opt/python@3.8/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1238                 encode_chunked=False):
#    1239         """Send a complete request to the server."""
# -> 1240         self._send_request(method, url, body, headers, encode_chunked)
#    1241
#    1242     def _send_request(self, method, url, body, headers, encode_chunked):
#
# /usr/local/opt/python@3.8/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             # default charset of iso-8859-1.
#    1285             body = _encode(body, 'body')
# -> 1286         self.endheaders(body, encode_chunked=encode_chunked)
#    1287
#    1288     def getresponse(self):
#
# /usr/local/opt/python@3.8/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in endheaders(self, message_body, encode_chunked)
#    1233         else:
#    1234             raise CannotSendHeader()
# -> 1235         self._send_output(message_body, encode_chunked=encode_chunked)
#    1236
#    1237     def request(self, method, url, body=None, headers={}, *,
#
# /usr/local/opt/python@3.8/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in _send_output(self, message_body, encode_chunked)
#    1004         msg = b"\r\n".join(self._buffer)
#    1005         del self._buffer[:]
# -> 1006         self.send(msg)
#    1007
#    1008         if message_body is not None:
#
# /usr/local/opt/python@3.8/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in send(self, data)
#     944         if self.sock is None:
#     945             if self.auto_open:
# --> 946                 self.connect()
#     947             else:
#     948                 raise NotConnected()
#
# /usr/local/opt/python@3.8/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in connect(self)
#    1407                 server_hostname = self.host
#    1408
# -> 1409             self.sock = self._context.wrap_socket(self.sock,
#    1410                                                   server_hostname=server_hostname)
#    1411
#
# /usr/local/opt/python@3.8/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     498         # SSLSocket class handles server_hostname encoding before it calls
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#     502             server_side=server_side,
#
# /usr/local/opt/python@3.8/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1038                         # non-blocking
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#    1042                 self.close()
#
# /usr/local/opt/python@3.8/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py in do_handshake(self, block)
#    1307             if timeout == 0.0 and block:
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#    1311             self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
data_set = pd.concat(frames)

data_set.set_index('sku', inplace=True)

data_set
# Out:
#                                                             name  \
# sku
# ON321C1KW-M11   ONLMONNA DRESS - Robe en jersey - ponderosa pine
# EV411N0AO-Q11                    Bottines à talons hauts - black
# CAO21I02P-N11                             Pullover - Olive green
# ON351L0F8-J11  ONLPEYTON 2 PACK EARRING - Boucles d'oreilles ...
# CO411A170-H11  CHUCK TAYLOR ALL STAR - Baskets montantes - fu...
# ...                                                          ...
# TH341E04P-N11  WOMEN’S APHRODITE CAPRI - Pantalons outdoor - ...
# MT711A054-O11                         EDEN - Espadrilles - brown
# NEG21C080-B11         FRONT BUTTON DRESS - Robe fourreau - beige
# RI521D08I-C11      SLUB FRILL - T-shirt à manches longues - grey
# M9121D13O-I11  MIT PUFFÄRMELN - T-shirt à manches longues - h...
#
#                                                       sizes  \
# sku
# ON321C1KW-M11                                 [XS, S, M, L]
# EV411N0AO-Q11                              [39, 40, 41, 42]
# CAO21I02P-N11                                     [S, M, L]
# ON351L0F8-J11                                    [One Size]
# CO411A170-H11  [36, 36.5, 37, 37.5, 39, 39.5, 41, 41.5, 42]
# ...                                                     ...
# TH341E04P-N11                                  [XS, S, XXL]
# MT711A054-O11                              [36, 38, 39, 40]
# NEG21C080-B11                                     [S, M, L]
# RI521D08I-C11                             [XS, S, M, L, XL]
# M9121D13O-I11                                        [S, L]
#
#                                                          url_key  \
# sku
# ON321C1KW-M11  only-onlmonna-dress-robe-en-jersey-ponderosa-p...
# EV411N0AO-Q11      evenandodd-boots-a-talons-black-ev411n0ao-q11
# CAO21I02P-N11         camaieu-pullover-olive-green-cao21i02p-n11
# ON351L0F8-J11  only-onlpeyton-2-pack-earring-boucles-doreille...
# CO411A170-H11  converse-chuck-taylor-all-star-baskets-montant...
# ...                                                          ...
# TH341E04P-N11  the-north-face-womens-aphrodite-capri-pantalon...
# MT711A054-O11        mtng-eden-sandales-compensees-mt711a054-o11
# NEG21C080-B11    nly-by-nelly-robe-en-jersey-beige-neg21c080-b11
# RI521D08I-C11  rich-and-royal-slub-frill-longsleeve-t-shirt-a...
# M9121D13O-I11  mango-t-shirt-mit-puffaermeln-t-shirt-a-manche...
#
#                                                            media  \
# sku
# ON321C1KW-M11  [{'path': 'ON/32/1C/1K/WM/11/ON321C1KW-M11@9.j...
# EV411N0AO-Q11  [{'path': 'EV/41/1N/0A/OQ/11/EV411N0AO-Q11@7.j...
# CAO21I02P-N11  [{'path': 'CA/O2/1I/02/PN/11/CAO21I02P-N11@10....
# ON351L0F8-J11  [{'path': 'ON/35/1L/0F/8J/11/ON351L0F8-J11@5.j...
# CO411A170-H11  [{'path': 'CO/41/1A/17/0H/11/CO411A170-H11@12....
# ...                                                          ...
# TH341E04P-N11  [{'path': 'TH/34/1E/04/PN/11/TH341E04P-N11@12....
# MT711A054-O11  [{'path': 'MT/71/1A/05/4O/11/MT711A054-O11@11....
# NEG21C080-B11  [{'path': 'NE/G2/1C/08/0B/11/NEG21C080-B11@4.j...
# RI521D08I-C11  [{'path': 'RI/52/1D/08/IC/11/RI521D08I-C11@4.j...
# M9121D13O-I11  [{'path': 'M9/12/1D/13/OI/11/M9121D13O-I11@11....
#
#                    brand_name  is_premium family_articles  \
# sku
# ON321C1KW-M11            ONLY       False              []
# EV411N0AO-Q11        Even&Odd       False              []
# CAO21I02P-N11         Camaïeu       False              []
# ON351L0F8-J11            ONLY       False              []
# CO411A170-H11        Converse       False              []
# ...                       ...         ...             ...
# TH341E04P-N11  The North Face       False              []
# MT711A054-O11            mtng       False              []
# NEG21C080-B11    Nly by Nelly       False              []
# RI521D08I-C11    Rich & Royal       False              []
# M9121D13O-I11           Mango       False              []
#
#                                                            flags  \
# sku
# ON321C1KW-M11  [{'key': 'discountRate', 'value': '-70%', 'tra...
# EV411N0AO-Q11  [{'key': 'discountRate', 'value': '-70%', 'tra...
# CAO21I02P-N11  [{'key': 'discountRate', 'value': '-43%', 'tra...
# ON351L0F8-J11  [{'key': 'discountRate', 'value': '-70%', 'tra...
# CO411A170-H11  [{'key': 'discountRate', 'value': 'Jusqu’à -45...
# ...                                                          ...
# TH341E04P-N11  [{'key': 'discountRate', 'value': '-35%', 'tra...
# MT711A054-O11  [{'key': 'discountRate', 'value': '-45%', 'tra...
# NEG21C080-B11  [{'key': 'discountRate', 'value': '-50%', 'tra...
# RI521D08I-C11  [{'key': 'discountRate', 'value': '-65%', 'tra...
# M9121D13O-I11  [{'key': 'discountRate', 'value': '-38%', 'tra...
#
#               product_group delivery_promises  ... price.promotional  \
# sku                                            ...
# ON321C1KW-M11      clothing                []  ...           12,49 €
# EV411N0AO-Q11          shoe                []  ...           13,69 €
# CAO21I02P-N11      clothing                []  ...           17,00 €
# ON351L0F8-J11   accessoires                []  ...            5,99 €
# CO411A170-H11          shoe                []  ...           40,95 €
# ...                     ...               ...  ...               ...
# TH341E04P-N11      clothing                []  ...           45,45 €
# MT711A054-O11          shoe                []  ...           30,45 €
# NEG21C080-B11      clothing                []  ...           19,95 €
# RI521D08I-C11      clothing                []  ...           20,95 €
# M9121D13O-I11      clothing                []  ...           15,99 €
#
#               price.has_different_prices  price.has_different_original_prices  \
# sku
# ON321C1KW-M11                      False                                False
# EV411N0AO-Q11                      False                                False
# CAO21I02P-N11                      False                                False
# ON351L0F8-J11                      False                                False
# CO411A170-H11                       True                                False
# ...                                  ...                                  ...
# TH341E04P-N11                      False                                False
# MT711A054-O11                      False                                False
# NEG21C080-B11                      False                                False
# RI521D08I-C11                      False                                False
# M9121D13O-I11                      False                                False
#
#                price.has_different_promotional_prices  \
# sku
# ON321C1KW-M11                                   False
# EV411N0AO-Q11                                   False
# CAO21I02P-N11                                   False
# ON351L0F8-J11                                   False
# CO411A170-H11                                    True
# ...                                               ...
# TH341E04P-N11                                   False
# MT711A054-O11                                   False
# NEG21C080-B11                                   False
# RI521D08I-C11                                   False
# M9121D13O-I11                                   False
#
#                price.has_discount_on_selected_sizes_only  amount outfits  \
# sku
# ON321C1KW-M11                                      False     NaN     NaN
# EV411N0AO-Q11                                      False     NaN     NaN
# CAO21I02P-N11                                      False     NaN     NaN
# ON351L0F8-J11                                      False     NaN     NaN
# CO411A170-H11                                      False     NaN     NaN
# ...                                                  ...     ...     ...
# TH341E04P-N11                                      False     NaN     NaN
# MT711A054-O11                                      False     NaN     NaN
# NEG21C080-B11                                      False     NaN     NaN
# RI521D08I-C11                                      False     NaN     NaN
# M9121D13O-I11                                      False     NaN     NaN
#
#               price.base_price condition condition_key
# sku
# ON321C1KW-M11              NaN       NaN           NaN
# EV411N0AO-Q11              NaN       NaN           NaN
# CAO21I02P-N11              NaN       NaN           NaN
# ON351L0F8-J11              NaN       NaN           NaN
# CO411A170-H11              NaN       NaN           NaN
# ...                        ...       ...           ...
# TH341E04P-N11              NaN       NaN           NaN
# MT711A054-O11              NaN       NaN           NaN
# NEG21C080-B11              NaN       NaN           NaN
# RI521D08I-C11              NaN       NaN           NaN
# M9121D13O-I11              NaN       NaN           NaN
#
# [18228 rows x 21 columns]

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here

data_set.groupby('brand_name').count().nlargest(1,'name')['name']
# Out:
# brand_name
# ONLY    595
# Name: name, dtype: int64

# %%
data_set['price.promotional'] = data_set['price.promotional'].str.replace('\xa0€', '').str.replace(',', '.')
data_set['price.promotional'] = data_set['price.promotional'].astype(float)

data_set['price.original'] = data_set['price.original'].str.replace('\xa0€', '').str.replace(',', '.')
data_set['price.original'] = data_set['price.original'].astype(float)

# %%
data_set['total_discount'] = data_set['price.original'] - data_set['price.promotional']

# %%
data_set.groupby('brand_name').sum().nlargest(1, 'total_discount')['total_discount']
# Out:
# brand_name
# Guess    13744.54
# Name: total_discount, dtype: float64
