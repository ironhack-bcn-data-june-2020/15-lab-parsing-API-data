# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here
url = 'https://www.zalando.fr/api/catalog/articles'

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here

#Import libraries

import json
import requests
import pandas as pd

# %%
# Define a function to get the information for each page

def get_page_info(num):
    offset = (num-1)*84
    page_url = 'https://www.zalando.fr/api/catalog/articles'
    params = {'categories':'promo-femme', 'limit':'84', 'offset':offset, 'sort':'popularity'}
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'}
    response = requests.get(page_url, headers=headers, params=params)
    return response.json()

# %%
# Get the information for the first page
response = get_page_info(1)

# Save it in a DataFrame
zal = pd.json_normalize(response['articles'])

# %%
# Get the total number of pages
total_pages = response['pagination']['page_count']

# Loop over all the pages to find all the information
# Page 1 is already in the goods dataframe so it's skipped
for page in range(1,total_pages+1):
    response = get_page_info(page)
    zal_aux = pd.json_normalize(response['articles'])
    zal = pd.concat([zal, zal_aux])

# %%
zal.head()
# Out:
#              sku                                               name  \
# 0  CAO21B07H-A11  JUPE TAILLE HAUTE CEINTURÉE - Jupe trapèze - c...
# 1  CAO21U02C-Q11                          Manteau classique - black
# 2  CAO21I08X-G11              GILET  MAILLE FILÉE - Gilet - rouille
# 3  LA251H01P-Q11                        NF1888PO_141 - Cabas - noir
# 4  AD111A0YA-A11  TRAINER  - Baskets basses - footwear white/glo...
#
#                                       sizes  \
# 0                  [34, 36, 38, 40, 44, 46]
# 1                      [36, 40, 42, 44, 46]
# 2                             [S, M, L, XL]
# 3                                [One Size]
# 4  [36, 42, 36 2/3, 37 1/3, 42 2/3, 43 1/3]
#
#                                              url_key  \
# 0  camaieu-jupe-taille-haute-ceinturee-jupe-trape...
# 1      camaieu-manteau-classique-black-cao21u02c-q11
# 2  camaieu-gilet-maille-filee-gilet-rouille-cao21...
# 3                  lacoste-cabas-black-la251h01p-q11
# 4  adidas-originals-trainer-baskets-basses-ad111a...
#
#                                                media        brand_name  \
# 0  [{'path': 'CA/O2/1B/07/HA/11/CAO21B07H-A11@8.1...           Camaïeu
# 1  [{'path': 'CA/O2/1U/02/CQ/11/CAO21U02C-Q11@12....           Camaïeu
# 2  [{'path': 'CA/O2/1I/08/XG/11/CAO21I08X-G11@15....           Camaïeu
# 3  [{'path': 'LA/25/1H/01/PQ/11/LA251H01P-Q11@17....           Lacoste
# 4  [{'path': 'AD/11/1A/0Y/AA/11/AD111A0YA-A11@12....  adidas Originals
#
#    is_premium family_articles  \
# 0       False              []
# 1       False              []
# 2       False              []
# 3       False              []
# 4       False              []
#
#                                                flags product_group  ...  \
# 0  [{'key': 'discountRate', 'value': '-60%', 'tra...      clothing  ...
# 1  [{'key': 'discountRate', 'value': '-60%', 'tra...      clothing  ...
# 2  [{'key': 'discountRate', 'value': '-40%', 'tra...      clothing  ...
# 3  [{'key': 'discountRate', 'value': '-10%', 'tra...   accessoires  ...
# 4  [{'key': 'discountRate', 'value': '-70%', 'tra...          shoe  ...
#
#   price.has_different_promotional_prices  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#   price.has_discount_on_selected_sizes_only  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#         tracking_information.metrigo_impression_urls  \
# 0  [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# 1  [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# 2  [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# 3                                                NaN
# 4                                                NaN
#
#               tracking_information.impression_beacon  \
# 0  https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# 1  https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# 2  https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# 3                                                NaN
# 4                                                NaN
#
#    tracking_information.source  amount  price.base_price outfits condition  \
# 0                          ccp     NaN               NaN     NaN       NaN
# 1                          ccp     NaN               NaN     NaN       NaN
# 2                          ccp     NaN               NaN     NaN       NaN
# 3                          NaN     NaN               NaN     NaN       NaN
# 4                          NaN     NaN               NaN     NaN       NaN
#
#   condition_key
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here

# Trending brand = the brand with more products
zal.groupby('brand_name').count().nlargest(1,'name')
# Out:
#              sku  name  sizes  url_key  media  is_premium  family_articles  \
# brand_name
# usha        1306  1306   1306     1306   1306        1306             1306
#
#             flags  product_group  delivery_promises  ...  \
# brand_name                                           ...
# usha         1306           1306               1306  ...
#
#             price.has_different_promotional_prices  \
# brand_name
# usha                                          1306
#
#             price.has_discount_on_selected_sizes_only  \
# brand_name
# usha                                             1306
#
#             tracking_information.metrigo_impression_urls  \
# brand_name
# usha                                                   0
#
#             tracking_information.impression_beacon  \
# brand_name
# usha                                             0
#
#             tracking_information.source  amount  price.base_price  outfits  \
# brand_name
# usha                                  0       0                 0        1
#
#             condition  condition_key
# brand_name
# usha                0              0
#
# [1 rows x 24 columns]

# %%
# Convert the original price to float type
zal['price.original'] = zal['price.original'].replace('\u20AC','',regex=True)
zal['price.original'] = zal['price.original'].str.replace(',', '.').replace('\xa0','').astype(float)
# Out:
# 0     25.99
# 1     89.99
# 2     25.99
# 3     94.95
# 4     99.95
#       ...
# 79    49.95
# 80    69.95
# 81    23.99
# 82    89.95
# 83    59.95
# Name: price.original, Length: 75012, dtype: float64

# %%
# Convert the promotional price to float type
zal['price.promotional'] = zal['price.promotional'].replace('\u20AC','',regex=True)
zal['price.promotional'] = zal['price.promotional'].str.replace(',', '.').replace('\xa0','')

zal['price.promotional'].loc[zal['price.promotional'].str.len() >7] = zal['price.promotional'].loc[zal['price.promotional'].str.len() >7].str.replace('\xa0','')
zal['price.promotional'] = zal['price.promotional'].astype(float)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
# Create a column with the difference of price
zal['PriceReduction'] = zal['price.original'] - zal['price.promotional'] 

# Find the product(s)with the highest discount:
zal.nlargest(5, 'PriceReduction')
# Out:
#               sku                                         name         sizes  \
# 7   HL421C03E-F11  FRINGE GOWN - Robe de cocktail - gold/combo  [34, 36, 38]
# 2   HL421C03O-F11    STRAPS GOWN - Robe de cocktail - rosegold  [34, 36, 38]
# 36  HL421C03U-F11                   Robe de soirée - rose gold  [34, 36, 38]
# 82  HL421C043-F11     FRINGE GOWN - Robe de soirée - rose gold  [34, 36, 38]
# 1   HL421C043-F11     FRINGE GOWN - Robe de soirée - rose gold  [34, 36, 38]
#
#                                               url_key  \
# 7   herve-leger-fringe-gown-robe-de-cocktail-goldc...
# 2   herve-leger-straps-gown-robe-de-cocktail-roseg...
# 36  herve-leger-robe-de-cocktail-rose-gold-hl421c0...
# 82  herve-leger-fringe-gown-robe-de-soiree-rose-go...
# 1   herve-leger-fringe-gown-robe-de-soiree-rose-go...
#
#                                                 media   brand_name  \
# 7   [{'path': 'HL/42/1C/03/EF/11/HL421C03E-F11@4.j...  Hervé Léger
# 2   [{'path': 'HL/42/1C/03/OF/11/HL421C03O-F11@9.j...  Hervé Léger
# 36  [{'path': 'HL/42/1C/03/UF/11/HL421C03U-F11@14....  Hervé Léger
# 82  [{'path': 'HL/42/1C/04/3F/11/HL421C043-F11@13....  Hervé Léger
# 1   [{'path': 'HL/42/1C/04/3F/11/HL421C043-F11@13....  Hervé Léger
#
#     is_premium                                    family_articles  \
# 7         True  [{'sku': 'HL421C03E-F11', 'url_key': 'herve-le...
# 2         True  [{'sku': 'HL421C03O-F11', 'url_key': 'herve-le...
# 36        True  [{'sku': 'HL421C03U-F11', 'url_key': 'herve-le...
# 82        True  [{'sku': 'HL421C043-F11', 'url_key': 'herve-le...
# 1         True  [{'sku': 'HL421C043-F11', 'url_key': 'herve-le...
#
#                                                 flags product_group  ...  \
# 7   [{'key': 'discountRate', 'value': '-70%', 'tra...      clothing  ...
# 2   [{'key': 'discountRate', 'value': '-60%', 'tra...      clothing  ...
# 36  [{'key': 'discountRate', 'value': '-70%', 'tra...      clothing  ...
# 82  [{'key': 'discountRate', 'value': '-70%', 'tra...      clothing  ...
# 1   [{'key': 'discountRate', 'value': '-70%', 'tra...      clothing  ...
#
#    price.has_discount_on_selected_sizes_only  \
# 7                                      False
# 2                                      False
# 36                                     False
# 82                                     False
# 1                                      False
#
#     tracking_information.metrigo_impression_urls  \
# 7                                            NaN
# 2                                            NaN
# 36                                           NaN
# 82                                           NaN
# 1                                            NaN
#
#     tracking_information.impression_beacon  tracking_information.source  \
# 7                                      NaN                          NaN
# 2                                      NaN                          NaN
# 36                                     NaN                          NaN
# 82                                     NaN                          NaN
# 1                                      NaN                          NaN
#
#     amount  price.base_price  outfits condition condition_key PriceReduction
# 7      NaN               NaN      NaN       NaN           NaN         1659.0
# 2      NaN               NaN      NaN       NaN           NaN         1269.0
# 36     NaN               NaN      NaN       NaN           NaN         1116.0
# 82     NaN               NaN      NaN       NaN           NaN         1064.0
# 1      NaN               NaN      NaN       NaN           NaN         1064.0
#
# [5 rows x 26 columns]

# %%
# sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices)
zal.sum()
