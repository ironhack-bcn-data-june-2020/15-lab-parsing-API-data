# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here

# Define the initial API  URL
api_url = 'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset=84&sort=popularity'

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here

# Import libraries
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
# Define a function to get the information of a selected page
def page_selection(k):
    # to select the first page
    offset = (k-1)*84
    api_url = 'https://www.zalando.fr/api/catalog/articles'
    headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36'}
    query = {'categories':'promo-femme','limit': 84,'offset':offset,'sort':'popularity'}
    response = requests.get(api_url, headers = headers, params=query)
    return response.json()

# %%
# Content of page 1
response = page_selection(1)
response
# Out:
# {'total_count': 181376,
#  'pagination': {'page_count': 892, 'current_page': 1, 'per_page': 84},
#  'sort': 'popularity',
#  'articles': [{'sku': 'NU511A019-Q11',
#    'name': 'Sandales - black',
#    'price': {'original': '84,99\xa0€',
#     'promotional': '59,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['37', '38', '39', '40'],
#    'url_key': 'inuovo-sandales-black-nu511a019-q11',
#    'media': [{'path': 'NU/51/1A/01/9Q/11/NU511A019-Q11@21.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Inuovo',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-29%',
#      'tracking_value': 'discount rate'},
#     {'key': 'sponsored', 'value': 'Sponsorisé', 'tracking_value': 'sponsored'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'tracking_information': {'metrigo_impression_urls': ['https://ccp-et.adtechlab.zalan.do/event/sbv?z=b072a84d-d74a-4244-906c-9cf07602300c&b=41e021d9-3ea9-4c01-aac6-3c710e09d3ef:30044518:NU511A019-Q11&c=30044518&a=30044520&s=NU511A019-Q11&is=1689&at=browser&cm=200000&ovm=531&r=0.0035521765239536762&ts=0&cs=754175393'],
#     'impression_beacon': 'https://ccp-et.adtechlab.zalan.do/event/sbv?z=b072a84d-d74a-4244-906c-9cf07602300c&b=41e021d9-3ea9-4c01-aac6-3c710e09d3ef:30044518:NU511A019-Q11&c=30044518&a=30044520&s=NU511A019-Q11&is=1689&at=browser&cm=200000&ovm=531&r=0.0035521765239536762&ts=0&cs=754175393',
#     'source': 'ccp'},
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NU511A049-O12',
#    'name': 'Sandales - mntrl coconut ncc',
#    'price': {'original': '69,99\xa0€',
#     'promotional': '59,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['37', '38', '39', '40', '41', '42'],
#    'url_key': 'inuovo-sandales-mntrl-coconut-ncc-nu511a049-o12',
#    'media': [{'path': 'NU/51/1A/04/9O/12/NU511A049-O12@15.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'NU/51/1A/04/9O/12/NU511A049-O12@14.1.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Inuovo',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-14%',
#      'tracking_value': 'discount rate'},
#     {'key': 'sponsored', 'value': 'Sponsorisé', 'tracking_value': 'sponsored'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'tracking_information': {'metrigo_impression_urls': ['https://ccp-et.adtechlab.zalan.do/event/sbv?z=b072a84d-d74a-4244-906c-9cf07602300c&b=41e021d9-3ea9-4c01-aac6-3c710e09d3ef:30044518:NU511A049-O12&c=30044518&a=30044520&s=NU511A049-O12&is=1689&at=browser&cm=200000&ovm=514&r=0.0026593604125082493&ts=0&cs=1607433433'],
#     'impression_beacon': 'https://ccp-et.adtechlab.zalan.do/event/sbv?z=b072a84d-d74a-4244-906c-9cf07602300c&b=41e021d9-3ea9-4c01-aac6-3c710e09d3ef:30044518:NU511A049-O12&c=30044518&a=30044520&s=NU511A049-O12&is=1689&at=browser&cm=200000&ovm=514&r=0.0026593604125082493&ts=0&cs=1607433433',
#     'source': 'ccp'},
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NU511A034-Q11',
#    'name': 'Sandales - black blk',
#    'price': {'original': '79,99\xa0€',
#     'promotional': '69,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '38', '41'],
#    'url_key': 'inuovo-sandales-black-blk-nu511a034-q11',
#    'media': [{'path': 'NU/51/1A/03/4Q/11/NU511A034-Q11@14.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Inuovo',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-13%',
#      'tracking_value': 'discount rate'},
#     {'key': 'sponsored', 'value': 'Sponsorisé', 'tracking_value': 'sponsored'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'tracking_information': {'metrigo_impression_urls': ['https://ccp-et.adtechlab.zalan.do/event/sbv?z=b072a84d-d74a-4244-906c-9cf07602300c&b=41e021d9-3ea9-4c01-aac6-3c710e09d3ef:30044518:NU511A034-Q11&c=30044518&a=30044520&s=NU511A034-Q11&is=1689&at=browser&cm=200000&ovm=508&r=0.002574739744886756&ts=0&cs=826704620'],
#     'impression_beacon': 'https://ccp-et.adtechlab.zalan.do/event/sbv?z=b072a84d-d74a-4244-906c-9cf07602300c&b=41e021d9-3ea9-4c01-aac6-3c710e09d3ef:30044518:NU511A034-Q11&c=30044518&a=30044520&s=NU511A034-Q11&is=1689&at=browser&cm=200000&ovm=508&r=0.002574739744886756&ts=0&cs=826704620',
#     'source': 'ccp'},
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'LA251H021-E11',
#    'name': 'Cabas - black warm sand',
#    'price': {'original': '119,95\xa0€',
#     'promotional': '89,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['One Size'],
#    'url_key': 'lacoste-reversible-cabas-la251h021-e11',
#    'media': [{'path': 'LA/25/1H/02/1E/11/LA251H021-E11@15.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LA/25/1H/02/1E/11/LA251H021-E11@14.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Lacoste',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'GU151M00P-F11',
#    'name': 'LADIES SPORT - Montre - rosegold-coloured',
#    'price': {'original': '289,95\xa0€',
#     'promotional': '86,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['One Size'],
#    'url_key': 'guess-montre-rosegold-coloured-gu151m00p-f11',
#    'media': [{'path': 'GU/15/1M/00/PF/11/GU151M00P-F11@6.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True},
#     {'path': 'GU/15/1M/00/PF/11/GU151M00P-F11@5.1.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Guess',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'NI111A0MZ-A11',
#    'name': 'RYZ 365 - Baskets basses - white/university red/midnight navy',
#    'price': {'original': '94,95\xa0€',
#     'promotional': '47,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36.5', '37.5', '38', '39', '40', '40.5', '41', '42', '43'],
#    'url_key': 'nike-sportswear-ryz-365-baskets-basses-whiteuniversity-redmidnight-navy-ni111a0mz-a11',
#    'media': [{'path': 'NI/11/1A/0M/ZA/11/NI111A0MZ-A11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True},
#     {'path': 'NI/11/1A/0M/ZA/11/NI111A0MZ-A11@8.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD111A0YA-A11',
#    'name': 'TRAINER  - Baskets basses - footwear white/glow purple/solar yellow',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '29,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '40', '36 2/3', '37 1/3', '39 1/3'],
#    'url_key': 'adidas-originals-trainer-baskets-basses-ad111a0ya-a11',
#    'media': [{'path': 'AD/11/1A/0Y/AA/11/AD111A0YA-A11@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'TO151H0EB-Q11',
#    'name': 'Cabas - black',
#    'price': {'original': '79,95\xa0€',
#     'promotional': '67,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['One Size'],
#    'url_key': 'tommy-hilfiger-cabas-black-to151h0eb-q11',
#    'media': [{'path': 'TO/15/1H/0E/BQ/11/TO151H0EB-Q11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'TO/15/1H/0E/BQ/11/TO151H0EB-Q11@10.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Tommy Hilfiger',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'VA211A078-Q11',
#    'name': 'SK8 PLATFORM 2.0 - Baskets montantes - black/true white',
#    'price': {'original': '94,95\xa0€',
#     'promotional': '85,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '36.5', '37', '38', '38.5', '39', '41', '42'],
#    'url_key': 'vans-sk8-platform-20-baskets-montantes-va211a078-q11',
#    'media': [{'path': 'VA/21/1A/07/8Q/11/VA211A078-Q11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Vans',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AN651H08X-D11',
#    'name': 'Pochette - silver',
#    'price': {'original': '19,99\xa0€',
#     'promotional': '5,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['One Size'],
#    'url_key': 'anna-field-pochette-silver-an651h08x-d11',
#    'media': [{'path': 'AN/65/1H/08/XD/11/AN651H08X-D11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'AN/65/1H/08/XD/11/AN651H08X-D11@10.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Anna Field',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'AN621C1J3-K11',
#    'name': 'Robe longue - evening blue',
#    'price': {'original': '39,99\xa0€',
#     'promotional': '11,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L'],
#    'url_key': 'anna-field-robe-de-cocktail-evening-blue-an621c1j3-k11',
#    'media': [{'path': 'AN/62/1C/1J/3K/11/AN621C1J3-K11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'AN/62/1C/1J/3K/11/AN621C1J3-K11@8.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Anna Field',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'RE011S06G-A11',
#    'name': 'CLUB C 85 - Baskets basses - white/light grey',
#    'price': {'original': '79,95\xa0€',
#     'promotional': '71,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5',
#     '36',
#     '37',
#     '37.5',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42'],
#    'url_key': 'reebok-classic-club-c-85-baskets-basses-re011s06g-a11',
#    'media': [{'path': 'RE/01/1S/06/GA/11/RE011S06G-A11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Reebok Classic',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -10%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'CO411A0BD-002',
#    'name': 'CHUCK TAYLOR ALL STAR HI - Baskets montantes - white',
#    'price': {'original': '69,95\xa0€',
#     'promotional': '62,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35',
#     '36',
#     '36.5',
#     '37',
#     '37.5',
#     '38',
#     '39',
#     '39.5',
#     '40',
#     '41',
#     '41.5',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '46',
#     '46.5',
#     '48',
#     '49',
#     '50',
#     '51.5',
#     '53',
#     '54'],
#    'url_key': 'converse-baskets-montantes-blanc-co411a0bd-002',
#    'media': [{'path': 'CO/41/1A/0B/D0/02/CO411A0BD-002@123.2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True},
#     {'path': 'CO/41/1A/0B/D0/02/CO411A0BD-002@118.2.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Converse',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'EV421D1EY-Q11',
#    'name': 'T-shirt à manches longues - black',
#    'price': {'original': '21,99\xa0€',
#     'promotional': '8,89\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M'],
#    'url_key': 'evenandodd-debardeur-black-ev421d1ey-q11',
#    'media': [{'path': 'EV/42/1D/1E/YQ/11/EV421D1EY-Q11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'EV/42/1D/1E/YQ/11/EV421D1EY-Q11@10.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Even&Odd',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-60%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AN611N0B1-Q11',
#    'name': 'LEATHER BOOTIES - Boots à talons - black',
#    'price': {'original': '74,99\xa0€',
#     'promotional': '22,49\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '39', '40', '41'],
#    'url_key': 'anna-field-boots-a-talons-black-an611n0b1-q11',
#    'media': [{'path': 'AN/61/1N/0B/1Q/11/AN611N0B1-Q11@5.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Anna Field',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'ON321E1FK-Q11',
#    'name': 'ONLKARMEN - Blouse - black',
#    'price': {'original': '19,99\xa0€',
#     'promotional': '15,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '40', '42', '44'],
#    'url_key': 'only-onlkarmen-blouse-on321e1fk-q11',
#    'media': [{'path': 'ON/32/1E/1F/KQ/11/ON321E1FK-Q11@4.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'ON/32/1E/1F/KQ/11/ON321E1FK-Q11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'ONLY',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'},
#     {'key': 'sponsored', 'value': 'Sponsorisé', 'tracking_value': 'sponsored'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'tracking_information': {'metrigo_impression_urls': ['https://ccp-et.adtechlab.zalan.do/event/sbv?z=b072a84d-d74a-4244-906c-9cf07602300c&b=41e021d9-3ea9-4c01-aac6-3c710e09d3ef:30048724:ON321E1FK-Q11&c=30048724&a=30048727&s=ON321E1FK-Q11&is=1689&at=browser&cm=100976&ovm=508&r=0.005037724040448666&ts=0&cs=1165258157'],
#     'impression_beacon': 'https://ccp-et.adtechlab.zalan.do/event/sbv?z=b072a84d-d74a-4244-906c-9cf07602300c&b=41e021d9-3ea9-4c01-aac6-3c710e09d3ef:30048724:ON321E1FK-Q11&c=30048724&a=30048727&s=ON321E1FK-Q11&is=1689&at=browser&cm=100976&ovm=508&r=0.005037724040448666&ts=0&cs=1165258157',
#     'source': 'ccp'},
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NU511A03P-Q11',
#    'name': 'Espadrilles - black blk',
#    'price': {'original': '79,99\xa0€',
#     'promotional': '49,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '38', '39', '40'],
#    'url_key': 'inuovo-sandales-a-plateforme-black-blk-nu511a03p-q11',
#    'media': [{'path': 'NU/51/1A/03/PQ/11/NU511A03P-Q11@19.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Inuovo',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-38%',
#      'tracking_value': 'discount rate'},
#     {'key': 'sponsored', 'value': 'Sponsorisé', 'tracking_value': 'sponsored'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'tracking_information': {'metrigo_impression_urls': ['https://ccp-et.adtechlab.zalan.do/event/sbv?z=b072a84d-d74a-4244-906c-9cf07602300c&b=41e021d9-3ea9-4c01-aac6-3c710e09d3ef:30044518:NU511A03P-Q11&c=30044518&a=30044520&s=NU511A03P-Q11&is=1689&at=browser&cm=200000&ovm=494&r=0.0025423807092010975&ts=0&cs=1518392904'],
#     'impression_beacon': 'https://ccp-et.adtechlab.zalan.do/event/sbv?z=b072a84d-d74a-4244-906c-9cf07602300c&b=41e021d9-3ea9-4c01-aac6-3c710e09d3ef:30044518:NU511A03P-Q11&c=30044518&a=30044520&s=NU511A03P-Q11&is=1689&at=browser&cm=200000&ovm=494&r=0.0025423807092010975&ts=0&cs=1518392904',
#     'source': 'ccp'},
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'DE121B078-B11',
#    'name': 'FAL QUIOS - Jupe longue - crudo',
#    'price': {'original': '129,95\xa0€',
#     'promotional': '38,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '40', '42', '44', '46'],
#    'url_key': 'desigual-fal-quios-jupe-longue-crudo-de121b078-b11',
#    'media': [{'path': 'DE/12/1B/07/8B/11/DE121B078-B11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'DE/12/1B/07/8B/11/DE121B078-B11@7.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Desigual',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'},
#     {'key': 'sponsored',
#      'value': 'Sponsorisé',
#      'tracking_value': 'sponsored'}],
#    'tracking_information': {'metrigo_impression_urls': ['https://ccp-et.adtechlab.zalan.do/event/sbv?z=b072a84d-d74a-4244-906c-9cf07602300c&b=41e021d9-3ea9-4c01-aac6-3c710e09d3ef:30045630:DE121B078-B11&c=30045630&a=30045631&s=DE121B078-B11&is=1689&at=browser&cm=120000&ovm=450&r=0.004120080731809139&ts=0&cs=1260480537'],
#     'impression_beacon': 'https://ccp-et.adtechlab.zalan.do/event/sbv?z=b072a84d-d74a-4244-906c-9cf07602300c&b=41e021d9-3ea9-4c01-aac6-3c710e09d3ef:30045630:DE121B078-B11&c=30045630&a=30045631&s=DE121B078-B11&is=1689&at=browser&cm=120000&ovm=450&r=0.004120080731809139&ts=0&cs=1260480537',
#     'source': 'ccp'},
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AN611B0B3-J11',
#    'name': 'Escarpins - nude',
#    'price': {'original': '39,99\xa0€',
#     'promotional': '15,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['37', '39', '40', '41', '42'],
#    'url_key': 'anna-field-escarpins-a-plateforme-nude-an611b0b3-j11',
#    'media': [{'path': 'AN/61/1B/0B/3J/11/AN611B0B3-J11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Anna Field',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-60%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD115B01K-A12',
#    'name': 'STAN SMITH - Baskets basses - ftwr white/core white/green',
#    'price': {'original': '89,95\xa0€',
#     'promotional': '76,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '38',
#     '40',
#     '42',
#     '44',
#     '46',
#     '48',
#     '36 2/3',
#     '37 1/3',
#     '38 2/3',
#     '39 1/3',
#     '40 2/3',
#     '41 1/3',
#     '42 2/3',
#     '43 1/3',
#     '44 2/3',
#     '45 1/3',
#     '46 2/3',
#     '47 1/3',
#     '48 2/3',
#     '49 1/3',
#     '50 2/3',
#     '51 1/3',
#     '52 2/3',
#     '53 1/3',
#     '54 2/3',
#     '55 2/3'],
#    'url_key': 'adidas-originals-stan-smith-baskets-basses-ad115b01k-a12',
#    'media': [{'path': 'AD/11/5B/01/KA/12/AD115B01K-A12@12.2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AN611A0N5-K11',
#    'name': 'LEATHER HEELED SANDALS - Sandales - dark blue',
#    'price': {'original': '59,99\xa0€',
#     'promotional': '17,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '38', '40'],
#    'url_key': 'anna-field-sandales-dark-blue-an611a0n5-k11',
#    'media': [{'path': 'AN/61/1A/0N/5K/11/AN611A0N5-K11@6.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Anna Field',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD111A0ZM-A11',
#    'name': 'SLEEK - Baskets basses - footwear white/crystal white/gold metallic',
#    'price': {'original': '89,95\xa0€',
#     'promotional': '35,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '36 2/3', '37 1/3', '39 1/3', '42 2/3'],
#    'url_key': 'adidas-originals-sleek-baskets-basses-footwear-whitecrystal-whitegold-metallic-ad111a0zm-a11',
#    'media': [{'path': 'AD/11/1A/0Z/MA/11/AD111A0ZM-A11@33.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -60%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'EV451H0PA-B11',
#    'name': 'Sac bandoulière - beige',
#    'price': {'original': '22,99\xa0€',
#     'promotional': '6,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['One Size'],
#    'url_key': 'evenandodd-sac-bandouliere-beige-ev451h0pa-b11',
#    'media': [{'path': 'EV/45/1H/0P/AB/11/EV451H0PA-B11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Even&Odd',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'EV421D1BW-A11',
#    'name': 'T-shirt imprimé - cloud dancer',
#    'price': {'original': '19,99\xa0€',
#     'promotional': '5,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'evenandodd-t-shirt-imprime-cloud-dancer-ev421d1bw-a11',
#    'media': [{'path': 'EV/42/1D/1B/WA/11/EV421D1BW-A11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'EV/42/1D/1B/WA/11/EV421D1BW-A11@8.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Even&Odd',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'EV421A088-Q11',
#    'name': 'Legging - black/white',
#    'price': {'original': '19,99\xa0€',
#     'promotional': '9,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L'],
#    'url_key': 'evenandodd-legging-blackwhite-ev421a088-q11',
#    'media': [{'path': 'EV/42/1A/08/8Q/11/EV421A088-Q11@4.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Even&Odd',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'EV451H0NV-B11',
#    'name': 'Cabas - taupe',
#    'price': {'original': '27,99\xa0€',
#     'promotional': '8,49\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['One Size'],
#    'url_key': 'evenandodd-sac-a-main-taupe-ev451h0nv-b11',
#    'media': [{'path': 'EV/45/1H/0N/VB/11/EV451H0NV-B11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'EV/45/1H/0N/VB/11/EV451H0NV-B11@12.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Even&Odd',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'EV421D1C9-Q11',
#    'name': 'LONGSLEEVE BODYSUIT WITH LADDE - Blouse - black',
#    'price': {'original': '32,99\xa0€',
#     'promotional': '9,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L'],
#    'url_key': 'evenandodd-longsleeve-bodysuit-with-ladde-blouse-black-ev421d1c9-q11',
#    'media': [{'path': 'EV/42/1D/1C/9Q/11/EV421D1C9-Q11@4.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'EV/42/1D/1C/9Q/11/EV421D1C9-Q11@5.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Even&Odd',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'EV451M020-J11',
#    'name': 'SET - Montre - rose/gold-coloured',
#    'price': {'original': '24,99\xa0€',
#     'promotional': '7,59\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['One Size'],
#    'url_key': 'evenandodd-set-montre-rosegold-coloured-ev451m020-j11',
#    'media': [{'path': 'EV/45/1M/02/0J/11/EV451M020-J11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Even&Odd',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'N1241E0XM-Q11',
#    'name': 'PEED - Collants - black/white',
#    'price': {'original': '69,95\xa0€',
#     'promotional': '27,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M'],
#    'url_key': 'nike-performance-peed-collants-n1241e0xm-q11',
#    'media': [{'path': 'N1/24/1E/0X/MQ/11/N1241E0XM-Q11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'N1/24/1E/0X/MQ/11/N1241E0XM-Q11@7.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Performance',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-60%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NE351B02H-C11',
#    'name': 'TECH 9FORTY - Casquette - grey',
#    'price': {'original': '27,95\xa0€',
#     'promotional': '23,75\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['One Size'],
#    'url_key': 'new-era-tech-9forty-casquette-grey-ne351b02h-c11',
#    'media': [{'path': 'NE/35/1B/02/HC/11/NE351B02H-C11@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'NE/35/1B/02/HC/11/NE351B02H-C11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'New Era',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'},
#     {'key': 'specialOffer',
#      'value': 'Exclusivité',
#      'tracking_value': 'special offer'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'LE221G02U-K11',
#    'name': 'EX BOYFRIEND TRUCKER - Veste en jean - soft as butter mid',
#    'price': {'original': '109,95\xa0€',
#     'promotional': '65,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L'],
#    'url_key': 'levisr-ex-boyfriend-trucker-veste-en-jean-soft-as-butter-mid-le221g02u-k11',
#    'media': [{'path': 'LE/22/1G/02/UK/11/LE221G02U-K11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LE/22/1G/02/UK/11/LE221G02U-K11@3.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'DOH81G005-Q11',
#    'name': 'FIJI SWIMSUIT - Maillot de bain - black',
#    'price': {'original': '26,95\xa0€',
#     'promotional': '24,25\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['38', '40', '42', '44', '46', '48'],
#    'url_key': 'dorina-curves-fiji-swimsuit-maillot-de-bain-black-doh81g005-q11',
#    'media': [{'path': 'DO/H8/1G/00/5Q/11/DOH81G005-Q11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'DO/H8/1G/00/5Q/11/DOH81G005-Q11@3.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'DORINA CURVES',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'beach_wear',
#    'delivery_promises': []},
#   {'sku': 'TO151H0EB-K11',
#    'name': 'Cabas - blue',
#    'price': {'original': '79,95\xa0€',
#     'promotional': '59,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['One Size'],
#    'url_key': 'tommy-hilfiger-cabas-blue-to151h0eb-k11',
#    'media': [{'path': 'TO/15/1H/0E/BK/11/TO151H0EB-K11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'TO/15/1H/0E/BK/11/TO151H0EB-K11@10.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Tommy Hilfiger',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'NU511A034-A11',
#    'name': 'Sandales - bone bne',
#    'price': {'original': '79,99\xa0€',
#     'promotional': '69,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '38', '39', '40'],
#    'url_key': 'inuovo-sandales-bone-bne-nu511a034-a11',
#    'media': [{'path': 'NU/51/1A/03/4A/11/NU511A034-A11@20.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Inuovo',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-13%',
#      'tracking_value': 'discount rate'},
#     {'key': 'sponsored', 'value': 'Sponsorisé', 'tracking_value': 'sponsored'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'tracking_information': {'metrigo_impression_urls': ['https://ccp-et.adtechlab.zalan.do/event/sbv?z=b072a84d-d74a-4244-906c-9cf07602300c&b=41e021d9-3ea9-4c01-aac6-3c710e09d3ef:30044518:NU511A034-A11&c=30044518&a=30044520&s=NU511A034-A11&is=1689&at=browser&cm=200000&ovm=446&r=0.0022539664059877396&ts=0&cs=1574061691'],
#     'impression_beacon': 'https://ccp-et.adtechlab.zalan.do/event/sbv?z=b072a84d-d74a-4244-906c-9cf07602300c&b=41e021d9-3ea9-4c01-aac6-3c710e09d3ef:30044518:NU511A034-A11&c=30044518&a=30044520&s=NU511A034-A11&is=1689&at=browser&cm=200000&ovm=446&r=0.0022539664059877396&ts=0&cs=1574061691',
#     'source': 'ccp'},
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NU511A035-O11',
#    'name': 'Sandales à plateforme - scissors scs',
#    'price': {'original': '99,99\xa0€',
#     'promotional': '59,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '39', '40', '41'],
#    'url_key': 'inuovo-sandales-a-plateforme-scissors-scs-nu511a035-o11',
#    'media': [{'path': 'NU/51/1A/03/5O/11/NU511A035-O11@14.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Inuovo',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'},
#     {'key': 'sponsored', 'value': 'Sponsorisé', 'tracking_value': 'sponsored'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'tracking_information': {'metrigo_impression_urls': ['https://ccp-et.adtechlab.zalan.do/event/sbv?z=b072a84d-d74a-4244-906c-9cf07602300c&b=41e021d9-3ea9-4c01-aac6-3c710e09d3ef:30044518:NU511A035-O11&c=30044518&a=30044520&s=NU511A035-O11&is=1689&at=browser&cm=200000&ovm=417&r=0.002230902900919318&ts=0&cs=4227044653'],
#     'impression_beacon': 'https://ccp-et.adtechlab.zalan.do/event/sbv?z=b072a84d-d74a-4244-906c-9cf07602300c&b=41e021d9-3ea9-4c01-aac6-3c710e09d3ef:30044518:NU511A035-O11&c=30044518&a=30044520&s=NU511A035-O11&is=1689&at=browser&cm=200000&ovm=417&r=0.002230902900919318&ts=0&cs=4227044653',
#     'source': 'ccp'},
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NU511A017-Q11',
#    'name': 'Sandales à plateforme - black blk',
#    'price': {'original': '84,99\xa0€',
#     'promotional': '79,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['37', '38', '39', '40', '41'],
#    'url_key': 'inuovo-sandales-black-blk-nu511a017-q11',
#    'media': [{'path': 'NU/51/1A/01/7Q/11/NU511A017-Q11@15.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Inuovo',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-6%',
#      'tracking_value': 'discount rate'},
#     {'key': 'sponsored', 'value': 'Sponsorisé', 'tracking_value': 'sponsored'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'tracking_information': {'metrigo_impression_urls': ['https://ccp-et.adtechlab.zalan.do/event/sbv?z=b072a84d-d74a-4244-906c-9cf07602300c&b=41e021d9-3ea9-4c01-aac6-3c710e09d3ef:30044518:NU511A017-Q11&c=30044518&a=30044520&s=NU511A017-Q11&is=1689&at=browser&cm=200000&ovm=367&r=0.0020898301154375076&ts=0&cs=1395348565'],
#     'impression_beacon': 'https://ccp-et.adtechlab.zalan.do/event/sbv?z=b072a84d-d74a-4244-906c-9cf07602300c&b=41e021d9-3ea9-4c01-aac6-3c710e09d3ef:30044518:NU511A017-Q11&c=30044518&a=30044520&s=NU511A017-Q11&is=1689&at=browser&cm=200000&ovm=367&r=0.0020898301154375076&ts=0&cs=1395348565',
#     'source': 'ccp'},
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI111A0M4-G11',
#    'name': 'AIR MAX VERONA - Baskets basses - burgundy/blue',
#    'price': {'original': '119,95\xa0€',
#     'promotional': '47,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36', '38', '38.5', '39', '40', '40.5', '43'],
#    'url_key': 'nike-sportswear-air-max-verona-baskets-basses-ni111a0m4-g11',
#    'media': [{'path': 'NI/11/1A/0M/4G/11/NI111A0M4-G11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': 'HOT DROP',
#      'tracking_value': 'mu_sneaker_releases'},
#     {'key': 'discountRate',
#      'value': '-60%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'LE222T02E-Q11',
#    'name': 'VINTAGE FIT TRUCKER UNISEX - Veste en jean - black trucker',
#    'price': {'original': '139,95\xa0€',
#     'promotional': '41,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'L', 'XL', 'XXL'],
#    'url_key': 'levisr-vintage-fit-trucker-veste-en-jean-le222t02e-q11',
#    'media': [{'path': 'LE/22/2T/02/EQ/11/LE222T02E-Q11@11.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LE/22/2T/02/EQ/11/LE222T02E-Q11@8.1.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'EV421I0AD-J11',
#    'name': 'Pullover - light pink',
#    'price': {'original': '29,99\xa0€',
#     'promotional': '9,09\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'L'],
#    'url_key': 'evenandodd-pullover-light-pink-ev421i0ad-j11',
#    'media': [{'path': 'EV/42/1I/0A/DJ/11/EV421I0AD-J11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'EV/42/1I/0A/DJ/11/EV421I0AD-J11@13.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Even&Odd',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AN611N09O-Q11',
#    'name': 'Boots à talons - black',
#    'price': {'original': '43,99\xa0€',
#     'promotional': '24,39\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '37', '38', '39', '40', '42'],
#    'url_key': 'anna-field-boots-a-talons-black-an611n09o-q11',
#    'media': [{'path': 'AN/61/1N/09/OQ/11/AN611N09O-Q11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Anna Field',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-45%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NE211A0BL-K11',
#    'name': 'WL574 - Baskets basses - blue',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '34,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['37.5', '38', '39', '40', '41'],
#    'url_key': 'new-balance-wl574-baskets-basses-blue-ne211a0bl-k11',
#    'media': [{'path': 'NE/21/1A/0B/LK/11/NE211A0BL-K11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'New Balance',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -65%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'OS411N02G-Q11',
#    'name': 'Boots à talons - black',
#    'price': {'original': '49,99\xa0€',
#     'promotional': '15,19\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['37', '40', '41'],
#    'url_key': 'only-shoes-boots-a-talons-black-os411n02g-q11',
#    'media': [{'path': 'OS/41/1N/02/GQ/11/OS411N02G-Q11@3.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'ONLY SHOES',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'},
#     {'key': 'specialOffer',
#      'value': 'Exclusivité',
#      'tracking_value': 'special offer'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'LE221J00U-A11',
#    'name': 'GRAPHIC SPORT - Sweat à capuche - marshmallow',
#    'price': {'original': '69,95\xa0€',
#     'promotional': '45,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XXS', 'XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'levisr-graphic-sport-sweatshirt-le221j00u-a11',
#    'media': [{'path': 'LE/22/1J/00/UA/11/LE221J00U-A11@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LE/22/1J/00/UA/11/LE221J00U-A11@13.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-35%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TO121J05E-K11',
#    'name': 'HERITAGE ZIP THROUGH HOODIE - veste en sweat zippée - midnight',
#    'price': {'original': '119,95\xa0€',
#     'promotional': '83,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL'],
#    'url_key': 'tommy-hilfiger-heritage-zip-through-hoodie-veste-en-sweat-zippee-midnight-to121j05e-k11',
#    'media': [{'path': 'TO/12/1J/05/EK/11/TO121J05E-K11@4.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'TO/12/1J/05/EK/11/TO121J05E-K11@10.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Tommy Hilfiger',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'CO411A163-C11',
#    'name': 'CHUCK TAYLOR ALL STAR LIFT - Baskets basses - mouse/moonstone violet/white',
#    'price': {'original': '79,95\xa0€',
#     'promotional': '43,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['37.5', '39.5', '40', '41', '42'],
#    'url_key': 'converse-chuck-taylor-all-star-lift-baskets-basses-mousemoonstone-violetwhite-co411a163-c11',
#    'media': [{'path': 'CO/41/1A/16/3C/11/CO411A163-C11@5.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Converse',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-45%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'VE121S05Z-K12',
#    'name': 'VMEMILY POCKET - Short - light blue denim',
#    'price': {'original': '24,99\xa0€',
#     'promotional': '8,79\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'L', 'XL'],
#    'url_key': 'vero-moda-vmemily-chambray-pocket-short-ve121s05z-k12',
#    'media': [{'path': 'VE/12/1S/05/ZK/12/VE121S05Z-K12@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'VE/12/1S/05/ZK/12/VE121S05Z-K12@14.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Vero Moda',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-65%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
# ...
#     {'key': 'caoutchouc', 'label': 'Caoutchouc'},
#     {'key': 'cotton', 'label': 'Coton'},
#     {'key': 'pure_cotton', 'label': 'coton (100%)'},
#     {'key': 'crocheted', 'label': 'Crocheté'},
#     {'key': 'leather', 'label': 'Cuir'},
#     {'key': 'cord', 'label': 'Côtelé'},
#     {'key': 'denim', 'label': 'Denim'},
#     {'key': 'lace', 'label': 'Dentelle'},
#     {'key': 'felt', 'label': 'Feutre'},
#     {'key': 'flanelette', 'label': 'Flanelle chaude'},
#     {'key': 'hardshell', 'label': 'Hardshell'},
#     {'key': 'imitation_leather', 'label': 'Imitation cuir'},
#     {'key': 'jersey', 'label': 'Jersey'},
#     {'key': 'wool', 'label': 'Laine'},
#     {'key': 'linen', 'label': 'Lin'},
#     {'key': 'pure_lyocell', 'label': 'lyocell (100%)'},
#     {'key': 'mesh', 'label': 'Mesh'},
#     {'key': 'chiffon', 'label': 'mousseline'},
#     {'key': 'sequins', 'label': 'paillettes'},
#     {'key': 'feathers', 'label': 'Plume'},
#     {'key': 'fleece', 'label': 'Polaire'},
#     {'key': 'polyester', 'label': 'Polyester'},
#     {'key': 'satin', 'label': 'Satin'},
#     {'key': 'softshell', 'label': 'Softshell'},
#     {'key': 'silk', 'label': 'Soie'},
#     {'key': 'rib', 'label': 'Strié'},
#     {'key': 'sweat', 'label': 'Sweat'},
#     {'key': 'synthetic', 'label': 'Synthétique'},
#     {'key': 'textile', 'label': 'Textile'},
#     {'key': 'braided', 'label': 'tressé'},
#     {'key': 'knitted_fabric', 'label': 'tricots'},
#     {'key': 'varnish', 'label': 'Verni'},
#     {'key': 'viscose', 'label': 'Viscose'}]},
#   {'key': 'sustainable',
#    'label': 'Éco-responsabilité',
#    'url_key': 'sustainable',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Éco-responsabilité'}],
#    'group_id': 'sustainable',
#    'description': 'Du commerce équitable au respect de l’environnement : bienvenue dans notre gamme de produits durables.'},
#   {'key': 'patterns',
#    'label': 'Motif',
#    'url_key': 'pattern',
#    'kind': 'values',
#    'values': [{'key': 'camouflage', 'label': 'camouflage'},
#     {'key': 'checked', 'label': 'carreaux'},
#     {'key': 'herring_bone', 'label': 'chevrons'},
#     {'key': 'flecked', 'label': 'chiné'},
#     {'key': 'plain', 'label': 'couleur unie'},
#     {'key': 'gradient', 'label': 'dégradé'},
#     {'key': 'burnout', 'label': 'dévoré'},
#     {'key': 'pinstripe', 'label': 'fines rayures'},
#     {'key': 'floral', 'label': 'floral'},
#     {'key': 'print', 'label': 'imprimé'},
#     {'key': 'animal_print', 'label': 'imprimé animal'},
#     {'key': 'leopard', 'label': 'imprimé léopard'},
#     {'key': 'photo_print', 'label': 'imprimé photo'},
#     {'key': 'colored', 'label': 'multicolore'},
#     {'key': 'paisley', 'label': 'Paisley/cachemire'},
#     {'key': 'striped', 'label': 'rayures'},
#     {'key': 'polka_dot', 'label': 'à pois'}]},
#   {'key': 'occasions',
#    'label': 'Occasion',
#    'url_key': 'occasion',
#    'kind': 'values',
#    'values': [{'key': 'evening_ball', 'label': 'bal de soirée'},
#     {'key': 'business', 'label': 'business'},
#     {'key': 'cocktail_party', 'label': 'cocktail'},
#     {'key': 'lounge_wear', 'label': 'confort/maison'},
#     {'key': 'formal_event', 'label': 'Festif'},
#     {'key': 'oktoberfest', 'label': 'festival de la bière'},
#     {'key': 'bridal', 'label': 'Looks de mariée'},
#     {'key': 'wedding', 'label': 'mariage'},
#     {'key': 'prom', 'label': 'remise des diplômes'},
#     {'key': 'party', 'label': 'soirée'}]},
#   {'key': 'assortment_areas',
#    'label': 'Coupes',
#    'url_key': 'assortment_area',
#    'kind': 'values',
#    'values': [{'key': 'STANDARD', 'label': 'Standard'},
#     {'key': 'MATERNITY', 'label': 'Maternité'},
#     {'key': 'PLUS_SIZE', 'label': 'Grandes tailles'},
#     {'key': 'PETITE', 'label': 'Petite'},
#     {'key': 'TALL', 'label': 'Grande'}]},
#   {'key': 'seasons',
#    'label': 'Saison',
#    'url_key': 'season_name',
#    'kind': 'values',
#    'values': [{'key': 'SUMMER', 'label': 'Printemps/Été'},
#     {'key': 'WINTER', 'label': 'Automne/Hiver'}]},
#   {'key': 'styles',
#    'label': 'Style',
#    'url_key': 'style',
#    'kind': 'values',
#    'values': [{'key': 'casual', 'label': 'casual'},
#     {'key': 'boho_dress', 'label': 'robe bohème'},
#     {'key': 'vintage_dress', 'label': 'robe vintage'},
#     {'key': 'elegant_dress', 'label': 'robe élégante'},
#     {'key': 'sporty', 'label': 'sportif'},
#     {'key': 'urban', 'label': 'Urbain'}]},
#   {'key': 'campaigns',
#    'label': 'Sélections',
#    'url_key': 'camp',
#    'kind': 'values',
#    'values': [{'key': 'mu_sneaker_releases', 'label': 'Hot Sneaker Drops'}]},
#   {'key': 'vegan',
#    'label': 'Végane',
#    'url_key': 'vegan',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Végane'}],
#    'group_id': 'vegan'},
#   {'key': 'shipped_by_zalando',
#    'label': 'Expédié par Zalando',
#    'url_key': 'shipped_by_zalando',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Expédié par Zalando'}],
#    'group_id': 'delivery'},
#   {'key': 'fr_delivery_24h',
#    'label': 'Livraison 24H',
#    'url_key': 'livraison-24h',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Livraison 24H'}],
#    'group_id': 'delivery'}],
#  'total_article_count': 181406,
#  'plusStatus': 'non-eligible',
#  'categoryTree': [{'label': 'Soldes',
#    'id': '8803',
#    'url_key': 'promo-femme',
#    'has_skus': True,
#    'selected': True,
#    'has_children': True,
#    'full_url': '/promo-femme/',
#    'children': [{'label': 'Vêtements',
#      'id': '8838',
#      'url_key': 'promo-mode-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-mode-femme/',
#      'children': [],
#      'article_count': 126267},
#     {'label': 'Chaussures',
#      'id': '8804',
#      'url_key': 'promo-chaussures-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-chaussures-femme/',
#      'children': [],
#      'article_count': 39748},
#     {'label': 'Sacs et accessoires',
#      'id': '8860',
#      'url_key': 'promo-accessoires-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-accessoires-femme/',
#      'children': [],
#      'article_count': 13671},
#     {'label': 'Lingerie',
#      'id': '8850',
#      'url_key': 'promo-lingerie-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-lingerie-femme/',
#      'children': [],
#      'article_count': 5863},
#     {'label': 'Luxe',
#      'id': '13429',
#      'url_key': 'promo-luxe-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-luxe-femme/',
#      'children': [],
#      'article_count': 10078},
#     {'label': 'Sport',
#      'id': '13286',
#      'url_key': 'promo-sport-femme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-sport-femme/',
#      'children': [],
#      'article_count': 10064},
#     {'label': 'Beauté',
#      'id': '13478',
#      'url_key': 'beaute-femme-promo',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/beaute-femme-promo/',
#      'children': [],
#      'article_count': 1196}],
#    'article_count': 181400}],
#  'sortingKeys': [{'type': 'popularity', 'dir': 'desc', 'label': 'Préférés'},
#   {'type': 'activation_date', 'dir': 'desc', 'label': 'Nouveautés'},
#   {'type': 'price_asc', 'dir': 'asc', 'label': 'Prix croissant'},
#   {'type': 'price_desc', 'dir': 'desc', 'label': 'Prix décroissant'},
#   {'type': 'sale', 'dir': 'desc', 'label': 'Soldes'}],
#  'breadcrumbs': [{'items': [{'label': 'Femme',
#      'url_key': 'femme',
#      'full_url': '/femme/'},
#     {'label': 'Soldes',
#      'url_key': 'promo-femme',
#      'full_url': '/promo-femme/'}]}],
#  'querySemantics': {'positive_filters': [{'key': 'categories',
#     'url_key': 'category',
#     'kind': 'values',
#     'values': [{'key': 'promo-femme',
#       'url_key': 'promo-femme',
#       'label': 'Soldes',
#       'seo_label': 'Soldes femme',
#       'reset_url': '/',
#       'id': '8803'}]}],
#   'negative_filters': [],
#   'reset_query_url': '/promo-femme/',
#   'reset_url': '/promo-femme/',
#   'app_url': '?urlKey=promo-femme&order=popularity&appdomainId=11'},
#  'articlesToShow': 84,
#  'octopusTests': [],
#  'locale': 'fr-FR',
#  'isLoggedIn': False,
#  'notification': None,
#  'resetFilters': {'categories': [{'key': 'promo-femme',
#     'url_key': 'promo-femme',
#     'label': 'Soldes',
#     'seo_label': 'Soldes femme',
#     'reset_url': '/',
#     'id': '8803'}]},
#  'selectedFilters': {'categories': ['promo-femme']},
#  'ssrArticleCount': 32,
#  'feedbackId': '5c112594708a306b9e611805',
#  'variants': {'fullWidthCatalog': False,
#   'premiumCatalog': False,
#   'myBrandsFilter': True,
#   'hideCategories': False,
#   'mobileLightFilters': True,
#   'truncatedCount': False,
#   'topTeaserPlaceholder': True,
#   'salesBannerCountdown': False,
#   'lazyArticleImages': False,
#   'useImg01': True},
#  'contentPositions': {'in-cat-carousel': 9,
#   'in-cat-carousel-mobile': 6,
#   'in-cat-carousel-fullwidth': 8,
#   'in-cat-teaser': 9,
#   'upper-in-cat-teaser': 5,
#   'entry-point-teasers': [7, 14, 20, 26],
#   'in-grid-filter': 4,
#   'search-dialog-mobile': [14],
#   'search-dialog-mobile-premium': [10],
#   'search-dialog-fullwidth': [24],
#   'search-dialog-premium': [16],
#   'search-dialog': [18],
#   'size-dialog': 12,
#   'sneaker-carousel': [12],
#   'outfits': [5, 14, 23],
#   'outfits-mobile': [5, 11, 17, 23],
#   'outfits-fullwidth': [7, 19, 31, 43],
#   'style-profile-follow-brands-banner': 6,
#   'style-profile-follow-brands-banner-mobile': 4,
#   'ingrid-teaser': 6,
#   'ingrid-premium-teaser': 5,
#   'ingrid-mobile-teaser': 4,
#   'ingrid-premium-mobile-teaser': 3},
#  'prideEnabled': False,
#  'lazyArticleImages': False,
#  'hideSearchTerm': False,
#  'iconPaths': {'filters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'mobileFilters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'flags': {'slow_delivery_flag': 'icons/clock.svg',
#    'fast_delivery_flag': 'icons/truck-fast-orange-3.svg',
#    'plus_delivery_flag': 'icons/plus-short-1.svg',
#    'zalando_plus': 'icons/zalando-plus.svg'}},
#  'teaser': {'content': {'creative_format': 'TEASER',
#    'brand': {'name': 'non-fashion brand', 'code': '-1'},
#    'pixels': ['https://crow.zalando.de/impressions/8924da7f-0e53-4d0e-a4f6-ec551c601e63/b072a84d-d74a-4244-906c-9cf07602300c/creative.png?slotId=21672e65-4b93-4cd0-9943-404c19eece9a&creativeId=fd084906-fda9-443b-9f9e-dd61ad85fd18&timeUnit=null&timeUnitCount=null&uuid=c416385f-3974-434c-a4cd-d939c4d245fe&bid=null&requestId=fe90f22f-3e17-449b-a25c-62619e6c2e28&adLocation=catalog&frontendType=browser&s=1DD5901848A37ADA839134AA4A2B2A52'],
#    'images': [{'aspect_ratio': None,
#      'max_screen_size': 1200,
#      'image_url': 'https://mosaic03.ztat.net/vgs/media/cropbyfocalarea/1600/299/3200/549/3500/spp-media-p1/c5c39f23371f4307b58061c1fcba8da9/b9fa5875d165441aaecdb9092c3f40dd.jpg',
#      'image_width': None},
#     {'aspect_ratio': None,
#      'max_screen_size': 600,
#      'image_url': 'https://mosaic03.ztat.net/vgs/media/cropbyfocalarea/480/231/960/462/2229/spp-media-p1/b61a933683b54966a88cf00f0dfbab32/5c80598840ff45faa028e447e2588f00.jpg',
#      'image_width': None}],
#    'creative_id': 'fd084906-fda9-443b-9f9e-dd61ad85fd18',
#    'campaign_id': '8924da7f-0e53-4d0e-a4f6-ec551c601e63',
#    'campaign_name': 'CAMS_CAMS_-_CW21_SS20_MSC_EoSS_SalesBanner_Wave4_Regular_All_FR_C_000000',
#    'campaign_source_id': 'NE2RZQEoQWu',
#    'text_fields': {'cta': "J'en profite\t\t\t\t",
#     'bg_color': '#940000',
#     'legal_claim': "*Les soldes d'été se terminent le 11/08/2020 à 23h59. Offre valable sur une sélection d'articles et dans la limite des stocks disponibles.\t",
#     'title': "SOLDES JUSQU'À -70% *\t\t",
#     'type': 'sales',
#     'sales_template': 'Discount',
#     'byline': "C'est bientôt la fin!\t\t",
#     'foreground_text_color': '#FFFFFF'},
#    'tracking_events': {'impression': {'type': 'advertising-event',
#      'advertising-category': 'category',
#      'advertising-action': 'teaser impression',
#      'advertising-parameter': {'channel_name': 'CF',
#       'campaign_name': 'CAMS_CAMS_-_CW21_SS20_MSC_EoSS_SalesBanner_Wave4_Regular_All_FR_C_000000',
#       'brand_code': '-1',
#       'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#       'flow_id': 'H63PAPiqjUyN+ZIu',
#       'shop_slot_id': 'catalog',
#       'campaign_source_id': 'NE2RZQEoQWu',
#       'request_id': 'fe90f22f-3e17-449b-a25c-62619e6c2e28',
#       'campaign_id': '8924da7f-0e53-4d0e-a4f6-ec551c601e63',
#       'creative_id': 'fd084906-fda9-443b-9f9e-dd61ad85fd18'}},
#     'view': {'type': 'teaser view',
#      'category': 'category',
#      'label': 'catalog.teaser',
#      'id': 'NE2RZQEoQWu',
#      'name': "SOLDES JUSQU'À -70% *\t\t",
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'campaign_name': 'CAMS_CAMS_-_CW21_SS20_MSC_EoSS_SalesBanner_Wave4_Regular_All_FR_C_000000',
#        'brand_code': '-1',
#        'adId': '4lwHsEODTtq',
#        'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#        'flow_id': 'H63PAPiqjUyN+ZIu',
#        'shop_slot_id': 'catalog',
#        'campaign_source_id': 'NE2RZQEoQWu',
#        'request_id': 'fe90f22f-3e17-449b-a25c-62619e6c2e28',
#        'campaign_id': '8924da7f-0e53-4d0e-a4f6-ec551c601e63',
#        'creative_id': 'fd084906-fda9-443b-9f9e-dd61ad85fd18'},
#       'dimension74': {'adId': '4lwHsEODTtq'}}},
#     'click': {'type': 'teaser click',
#      'category': 'category',
#      'label': 'catalog.teaser',
#      'id': 'NE2RZQEoQWu',
#      'name': "SOLDES JUSQU'À -70% *\t\t",
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'campaign_name': 'CAMS_CAMS_-_CW21_SS20_MSC_EoSS_SalesBanner_Wave4_Regular_All_FR_C_000000',
#        'brand_code': '-1',
#        'adId': '4lwHsEODTtq',
#        'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#        'flow_id': 'H63PAPiqjUyN+ZIu',
#        'shop_slot_id': 'catalog',
#        'campaign_source_id': 'NE2RZQEoQWu',
#        'request_id': 'fe90f22f-3e17-449b-a25c-62619e6c2e28',
#        'campaign_id': '8924da7f-0e53-4d0e-a4f6-ec551c601e63',
#        'creative_id': 'fd084906-fda9-443b-9f9e-dd61ad85fd18'},
#       'dimension74': {'adId': '4lwHsEODTtq'}}}},
#    'view_pixels': ['https://crow.zalando.de/views/8924da7f-0e53-4d0e-a4f6-ec551c601e63/b072a84d-d74a-4244-906c-9cf07602300c/creative.png?slotId=21672e65-4b93-4cd0-9943-404c19eece9a&creativeId=fd084906-fda9-443b-9f9e-dd61ad85fd18&timeUnit=null&timeUnitCount=null&uuid=0c990bbe-5622-49fc-bbd2-0d6c47c63e7a&bid=null&requestId=fe90f22f-3e17-449b-a25c-62619e6c2e28&adLocation=catalog&frontendType=browser&s=322695ACF863B6E3D82EC00E3A9CABDC'],
#    'tracking_data': {'explicit_tracking_params': {'flow_id': 'H63PAPiqjUyN+ZIu',
#      'entity_id': None,
#      'shop_slot_id': 'catalog',
#      'brand_code': '-1',
#      'campaign_source_id': 'NE2RZQEoQWu',
#      'campaign_id': '8924da7f-0e53-4d0e-a4f6-ec551c601e63',
#      'creative_id': 'fd084906-fda9-443b-9f9e-dd61ad85fd18',
#      'campaign_name': 'CAMS_CAMS_-_CW21_SS20_MSC_EoSS_SalesBanner_Wave4_Regular_All_FR_C_000000',
#      'target_entity_id': None},
#     'cf_tracking_params': {'channel_name': 'CF',
#      'campaign_name': 'CAMS_CAMS_-_CW21_SS20_MSC_EoSS_SalesBanner_Wave4_Regular_All_FR_C_000000',
#      'brand_code': '-1',
#      'adId': '4lwHsEODTtq',
#      'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#      'flow_id': 'H63PAPiqjUyN+ZIu',
#      'shop_slot_id': 'catalog',
#      'campaign_source_id': 'NE2RZQEoQWu',
#      'request_id': 'fe90f22f-3e17-449b-a25c-62619e6c2e28',
#      'campaign_id': '8924da7f-0e53-4d0e-a4f6-ec551c601e63',
#      'creative_id': 'fd084906-fda9-443b-9f9e-dd61ad85fd18'}},
#    'click_url': 'https://www.zalando.fr/promo-femme/&Sale=True'},
#   'channel_name': 'CF',
#   'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a'},
#  'inCatalogTeaser': None,
#  'entryPointTeasers': None,
#  'upperInCatTeaser': None,
#  'collection': None,
#  'carouselTeaser': None,
#  'wishlist': None,
#  'pills': None,
#  'sizeOnboardingDialog': None}

# %%
# Flatten data
goods = json_normalize(response['articles'])
goods
# Out:
#               sku                                           name  \
# 0   NU511A019-Q11                               Sandales - black
# 1   NU511A049-O12                   Sandales - mntrl coconut ncc
# 2   NU511A034-Q11                           Sandales - black blk
# 3   LA251H021-E11                        Cabas - black warm sand
# 4   GU151M00P-F11      LADIES SPORT - Montre - rosegold-coloured
# ..            ...                                            ...
# 79  OS411A03C-A11  ONLSKYE CROC TOE CAP - Baskets basses - white
# 80  M9121A1XZ-M11              RELAX - Pantalon classique - grün
# 81  AN611B0B2-Q11              LEATHER PUMPS - Escarpins - black
# 82  GU151H1J5-Q11                   DIGITAL - Sac à main - black
# 83  BU311A0AT-B11                         JULIA - Sandales - tan
#
#                            sizes  \
# 0               [37, 38, 39, 40]
# 1       [37, 38, 39, 40, 41, 42]
# 2               [36, 37, 38, 41]
# 3                     [One Size]
# 4                     [One Size]
# ..                           ...
# 79          [36, 37, 38, 39, 40]
# 80              [36, 38, 44, 46]
# 81  [36, 37, 38, 39, 40, 41, 42]
# 82                    [One Size]
# 83          [36, 37, 38, 39, 40]
#
#                                               url_key  \
# 0                 inuovo-sandales-black-nu511a019-q11
# 1     inuovo-sandales-mntrl-coconut-ncc-nu511a049-o12
# 2             inuovo-sandales-black-blk-nu511a034-q11
# 3              lacoste-reversible-cabas-la251h021-e11
# 4        guess-montre-rosegold-coloured-gu151m00p-f11
# ..                                                ...
# 79  only-shoes-onlskye-croc-toe-cap-baskets-basses...
# 80       mango-relax-pantalon-classique-m9121a1xz-m11
# 81           anna-field-escarpins-black-an611b0b2-q11
# 82               guess-sac-a-main-black-gu151h1j5-q11
# 83           buffalo-julia-sandales-tan-bu311a0at-b11
#
#                                                 media  brand_name  is_premium  \
# 0   [{'path': 'NU/51/1A/01/9Q/11/NU511A019-Q11@21....      Inuovo       False
# 1   [{'path': 'NU/51/1A/04/9O/12/NU511A049-O12@15....      Inuovo       False
# 2   [{'path': 'NU/51/1A/03/4Q/11/NU511A034-Q11@14....      Inuovo       False
# 3   [{'path': 'LA/25/1H/02/1E/11/LA251H021-E11@15....     Lacoste       False
# 4   [{'path': 'GU/15/1M/00/PF/11/GU151M00P-F11@6.1...       Guess       False
# ..                                                ...         ...         ...
# 79  [{'path': 'OS/41/1A/03/CA/11/OS411A03C-A11@3.j...  ONLY SHOES       False
# 80  [{'path': 'M9/12/1A/1X/ZM/11/M9121A1XZ-M11@11....       Mango       False
# 81  [{'path': 'AN/61/1B/0B/2Q/11/AN611B0B2-Q11@10....  Anna Field       False
# 82  [{'path': 'GU/15/1H/1J/5Q/11/GU151H1J5-Q11@4.j...       Guess       False
# 83  [{'path': 'BU/31/1A/0A/TB/11/BU311A0AT-B11@5.j...     Buffalo       False
#
#    family_articles                                              flags  \
# 0               []  [{'key': 'discountRate', 'value': '-29%', 'tra...
# 1               []  [{'key': 'discountRate', 'value': '-14%', 'tra...
# 2               []  [{'key': 'discountRate', 'value': '-13%', 'tra...
# 3               []  [{'key': 'discountRate', 'value': '-25%', 'tra...
# 4               []  [{'key': 'discountRate', 'value': '-70%', 'tra...
# ..             ...                                                ...
# 79              []  [{'key': 'discountRate', 'value': '-70%', 'tra...
# 80              []  [{'key': 'discountRate', 'value': '-60%', 'tra...
# 81              []  [{'key': 'discountRate', 'value': '-70%', 'tra...
# 82              []  [{'key': 'discountRate', 'value': '-50%', 'tra...
# 83              []  [{'key': 'discountRate', 'value': '-70%', 'tra...
#
#    product_group delivery_promises price.original price.promotional  \
# 0           shoe                []        84,99 €           59,95 €
# 1           shoe                []        69,99 €           59,95 €
# 2           shoe                []        79,99 €           69,95 €
# 3    accessoires                []       119,95 €           89,95 €
# 4    accessoires                []       289,95 €           86,95 €
# ..           ...               ...            ...               ...
# 79          shoe                []        37,99 €           11,49 €
# 80      clothing                []        39,99 €           15,99 €
# 81          shoe                []        69,99 €           20,99 €
# 82   accessoires                []       145,00 €           72,50 €
# 83          shoe                []        64,99 €           19,49 €
#
#     price.has_different_prices  price.has_different_original_prices  \
# 0                        False                                False
# 1                        False                                False
# 2                        False                                False
# 3                        False                                False
# 4                        False                                False
# ..                         ...                                  ...
# 79                       False                                False
# 80                       False                                False
# 81                       False                                False
# 82                       False                                False
# 83                       False                                False
#
#     price.has_different_promotional_prices  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# ..                                     ...
# 79                                   False
# 80                                   False
# 81                                   False
# 82                                   False
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ..                                        ...
# 79                                      False
# 80                                      False
# 81                                      False
# 82                                      False
# 83                                      False
#
#          tracking_information.metrigo_impression_urls  \
# 0   [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# 1   [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# 2   [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
#
#                tracking_information.impression_beacon  \
# 0   https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# 1   https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# 2   https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
#
#    tracking_information.source
# 0                          ccp
# 1                          ccp
# 2                          ccp
# 3                          NaN
# 4                          NaN
# ..                         ...
# 79                         NaN
# 80                         NaN
# 81                         NaN
# 82                         NaN
# 83                         NaN
#
# [84 rows x 20 columns]

# %%
# Get the total number of pages
total_pages = response['pagination']['page_count']
(f'Total pages: {total_pages}')
# Out:
# 'Total pages: 892'

# %%
# For loop to iterate from page 2 to page count
df = pd.DataFrame()
for page in range(total_pages):
    offset=84*page
    api_url = f'https://www.zalando.fr/api/catalog/articles'
    headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36'}
    query = {'categories':'promo-femme','limit': 84,'offset':{offset},'sort':'popularity'}
    response = requests.get(api_url, headers = headers, params=query)
    results = response.json()
    goods = json_normalize(results['articles'])
    goods.set_index('sku', inplace = True)
    df = df.append(goods, sort=False)

df.head()
# Out:
#                                                     name  \
# sku
# NU511A019-Q11                           Sandales - black
# NU511A049-O12               Sandales - mntrl coconut ncc
# NU511A03P-Q11                    Espadrilles - black blk
# LA251H021-E11                    Cabas - black warm sand
# GU151M00P-F11  LADIES SPORT - Montre - rosegold-coloured
#
#                                   sizes  \
# sku
# NU511A019-Q11          [37, 38, 39, 40]
# NU511A049-O12  [37, 38, 39, 40, 41, 42]
# NU511A03P-Q11      [36, 37, 38, 39, 40]
# LA251H021-E11                [One Size]
# GU151M00P-F11                [One Size]
#
#                                                          url_key  \
# sku
# NU511A019-Q11                inuovo-sandales-black-nu511a019-q11
# NU511A049-O12    inuovo-sandales-mntrl-coconut-ncc-nu511a049-o12
# NU511A03P-Q11  inuovo-sandales-a-plateforme-black-blk-nu511a0...
# LA251H021-E11             lacoste-reversible-cabas-la251h021-e11
# GU151M00P-F11       guess-montre-rosegold-coloured-gu151m00p-f11
#
#                                                            media brand_name  \
# sku
# NU511A019-Q11  [{'path': 'NU/51/1A/01/9Q/11/NU511A019-Q11@21....     Inuovo
# NU511A049-O12  [{'path': 'NU/51/1A/04/9O/12/NU511A049-O12@15....     Inuovo
# NU511A03P-Q11  [{'path': 'NU/51/1A/03/PQ/11/NU511A03P-Q11@19....     Inuovo
# LA251H021-E11  [{'path': 'LA/25/1H/02/1E/11/LA251H021-E11@15....    Lacoste
# GU151M00P-F11  [{'path': 'GU/15/1M/00/PF/11/GU151M00P-F11@6.1...      Guess
#
#                is_premium family_articles  \
# sku
# NU511A019-Q11       False              []
# NU511A049-O12       False              []
# NU511A03P-Q11       False              []
# LA251H021-E11       False              []
# GU151M00P-F11       False              []
#
#                                                            flags  \
# sku
# NU511A019-Q11  [{'key': 'discountRate', 'value': '-29%', 'tra...
# NU511A049-O12  [{'key': 'discountRate', 'value': '-14%', 'tra...
# NU511A03P-Q11  [{'key': 'discountRate', 'value': '-38%', 'tra...
# LA251H021-E11  [{'key': 'discountRate', 'value': '-25%', 'tra...
# GU151M00P-F11  [{'key': 'discountRate', 'value': '-70%', 'tra...
#
#               product_group delivery_promises  ...  \
# sku                                            ...
# NU511A019-Q11          shoe                []  ...
# NU511A049-O12          shoe                []  ...
# NU511A03P-Q11          shoe                []  ...
# LA251H021-E11   accessoires                []  ...
# GU151M00P-F11   accessoires                []  ...
#
#               price.has_different_promotional_prices  \
# sku
# NU511A019-Q11                                  False
# NU511A049-O12                                  False
# NU511A03P-Q11                                  False
# LA251H021-E11                                  False
# GU151M00P-F11                                  False
#
#               price.has_discount_on_selected_sizes_only  \
# sku
# NU511A019-Q11                                     False
# NU511A049-O12                                     False
# NU511A03P-Q11                                     False
# LA251H021-E11                                     False
# GU151M00P-F11                                     False
#
#                     tracking_information.metrigo_impression_urls  \
# sku
# NU511A019-Q11  [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# NU511A049-O12  [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# NU511A03P-Q11  [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# LA251H021-E11                                                NaN
# GU151M00P-F11                                                NaN
#
#                           tracking_information.impression_beacon  \
# sku
# NU511A019-Q11  https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# NU511A049-O12  https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# NU511A03P-Q11  https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# LA251H021-E11                                                NaN
# GU151M00P-F11                                                NaN
#
#                tracking_information.source  outfits amount price.base_price  \
# sku
# NU511A019-Q11                          ccp      NaN    NaN              NaN
# NU511A049-O12                          ccp      NaN    NaN              NaN
# NU511A03P-Q11                          ccp      NaN    NaN              NaN
# LA251H021-E11                          NaN      NaN    NaN              NaN
# GU151M00P-F11                          NaN      NaN    NaN              NaN
#
#               condition condition_key
# sku
# NU511A019-Q11       NaN           NaN
# NU511A049-O12       NaN           NaN
# NU511A03P-Q11       NaN           NaN
# LA251H021-E11       NaN           NaN
# GU151M00P-F11       NaN           NaN
#
# [5 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['name', 'sizes', 'url_key', 'media', 'brand_name', 'is_premium',
#        'family_articles', 'flags', 'product_group', 'delivery_promises',
#        'price.original', 'price.promotional', 'price.has_different_prices',
#        'price.has_different_original_prices',
#        'price.has_different_promotional_prices',
#        'price.has_discount_on_selected_sizes_only',
#        'tracking_information.metrigo_impression_urls',
#        'tracking_information.impression_beacon', 'tracking_information.source',
#        'outfits', 'amount', 'price.base_price', 'condition', 'condition_key'],
#       dtype='object')

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here

# Trending brand
df.brand_name.value_counts().index[0]
# Out:
# 'usha'

# %%
df.dtypes
# Out:
# name                                            object
# sizes                                           object
# url_key                                         object
# media                                           object
# brand_name                                      object
# is_premium                                        bool
# family_articles                                 object
# flags                                           object
# product_group                                   object
# delivery_promises                               object
# price.original                                  object
# price.promotional                               object
# price.has_different_prices                        bool
# price.has_different_original_prices               bool
# price.has_different_promotional_prices            bool
# price.has_discount_on_selected_sizes_only         bool
# tracking_information.metrigo_impression_urls    object
# tracking_information.impression_beacon          object
# tracking_information.source                     object
# outfits                                         object
# amount                                          object
# price.base_price                                object
# condition                                       object
# condition_key                                   object
# dtype: object

# %%
# change format of original price
df['price.original'] = df['price.original'].str.replace('\d\xa0','').str.replace('\d\xa0[0*?]','').str.replace(',','.')
df['price.original'] = df['price.original'].str.replace('€','')
df['price.original']
# Out:
# sku
# NU511A019-Q11     84.9
# NU511A049-O12     69.9
# NU511A03P-Q11     79.9
# LA251H021-E11    119.9
# GU151M00P-F11    289.9
#                  ...
# IC621U00N-I11    189.9
# 5DE41D02K-A11     44.9
# M9121C40L-Q11     39.9
# 1US21C06A-K11     99.9
# 4DR21U03E-A11    109.9
# Name: price.original, Length: 74928, dtype: object

# %%
# change format of original price
df['price.promotional'] = df['price.promotional'].str.replace('\d\xa0','').str.replace('\d\xa0[0*?]','').str.replace(',','.')
df['price.promotional'] = df['price.promotional'].str.replace('€','')
df['price.promotional']
# Out:
# sku
# NU511A019-Q11    59.9
# NU511A049-O12    59.9
# NU511A03P-Q11    49.9
# LA251H021-E11    89.9
# GU151M00P-F11    86.9
#                  ...
# IC621U00N-I11    84.1
# 5DE41D02K-A11    20.4
# M9121C40L-Q11    19.9
# 1US21C06A-K11    49.9
# 4DR21U03E-A11    49.9
# Name: price.promotional, Length: 74928, dtype: object

# %%
df['price.original'] = df['price.original'].astype(float)

# %%
df['price.promotional'] = df['price.promotional'].astype(float)

# %%
# Create a new column with the discount
df['discount'] = df['price.original'].astype(float) - df['price.promotional'].astype(float)
df['discount']
# Out:
# sku
# NU511A019-Q11     25.0
# NU511A049-O12     10.0
# NU511A03P-Q11     30.0
# LA251H021-E11     30.0
# GU151M00P-F11    203.0
#                  ...
# IC621U00N-I11    105.8
# 5DE41D02K-A11     24.5
# M9121C40L-Q11     20.0
# 1US21C06A-K11     50.0
# 4DR21U03E-A11     60.0
# Name: discount, Length: 74928, dtype: float64

# %%
# The first 10 products with the highest discount
total_discount = df.groupby('brand_name').sum().nlargest(10,'discount')
total_discount
# Out:
#                      is_premium  price.original  price.promotional  \
# brand_name
# myMo                        0.0        156425.3            77487.0
# usha                        0.0        170391.3            93468.7
# DreiMaster                  0.0        141977.0            74444.7
# Guess                       0.0         91916.9            51861.6
# Schmuddelwedda              0.0         79067.6            46541.0
# Silvio Tossi                0.0         45672.0            13355.1
# HUGO                      232.0         42201.3            20870.8
# IVY & OAK                   0.0         49154.2            28175.8
# faina                       0.0         81334.2            61212.1
# MM6 Maison Margiela       103.0         37715.0            18468.3
#
#                      price.has_different_prices  \
# brand_name
# myMo                                      963.0
# usha                                     1009.0
# DreiMaster                                952.0
# Guess                                      73.0
# Schmuddelwedda                            388.0
# Silvio Tossi                                0.0
# HUGO                                       59.0
# IVY & OAK                                  76.0
# faina                                     135.0
# MM6 Maison Margiela                         0.0
#
#                      price.has_different_original_prices  \
# brand_name
# myMo                                                 0.0
# usha                                                 0.0
# DreiMaster                                           0.0
# Guess                                                1.0
# Schmuddelwedda                                       0.0
# Silvio Tossi                                         0.0
# HUGO                                                 0.0
# IVY & OAK                                            2.0
# faina                                                0.0
# MM6 Maison Margiela                                  0.0
#
#                      price.has_different_promotional_prices  \
# brand_name
# myMo                                                  963.0
# usha                                                 1009.0
# DreiMaster                                            952.0
# Guess                                                  72.0
# Schmuddelwedda                                        388.0
# Silvio Tossi                                            0.0
# HUGO                                                   59.0
# IVY & OAK                                              74.0
# faina                                                 135.0
# MM6 Maison Margiela                                     0.0
#
#                      price.has_discount_on_selected_sizes_only  discount
# brand_name
# myMo                                                       0.0   78938.3
# usha                                                       0.0   76922.6
# DreiMaster                                                 0.0   67532.3
# Guess                                                      0.0   40055.3
# Schmuddelwedda                                             0.0   32526.6
# Silvio Tossi                                               0.0   32316.9
# HUGO                                                       0.0   21330.5
# IVY & OAK                                                  0.0   20978.4
# faina                                                      0.0   20122.1
# MM6 Maison Margiela                                        0.0   19246.7

# %%
# The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices) ?
# I don't really understand the question

sum_discounts = df['price.promotional'].sum() / df['price.original'].sum()
sum_discounts
# Out:
# 0.6471238292709032
