# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here
url = "https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset=0&sort=sale"

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_2) Chrome/71.0.3578.98 Safari/537.36"}

# %%
response = requests.get(url, headers=headers)
results = response.json()
flattened_data = pd.json_normalize(results)
flattened_data_art = pd.json_normalize(flattened_data.articles[0])
flattened_data_art.head()
# Out:
#              sku                                               name  \
# 0  NI115O00M-Q11  P-6000 - Baskets basses - black/lemon/platinum...
# 1  NI115O00E-A11  GHOSWIFT - Baskets basses - white/black/wolf g...
# 2  4BE22Q04D-K11                   ROLL NECK - Pullover - dark blue
# 3  4BE22Q04D-Q11                       ROLL NECK - Pullover - black
# 4  4BE22Q04D-Q12                   ROLL NECK - Pullover - anthrazit
#
#                                                sizes  \
# 0  [35.5, 36, 36.5, 37.5, 38, 38.5, 39, 40, 40.5,...
# 1  [35.5, 36, 36.5, 37.5, 38, 38.5, 39, 40, 40.5,...
# 2                                 [S, M, L, XL, XXL]
# 3                                       [L, XL, XXL]
# 4                             [XS, S, M, L, XL, XXL]
#
#                                              url_key  \
# 0  nike-sportswear-p-6000-baskets-basses-ni115o00...
# 1  nike-sportswear-ghoswift-baskets-basses-whiteb...
# 2          benetton-pullover-dark-blue-4be22q04d-k11
# 3              benetton-pullover-black-4be22q04d-q11
# 4          benetton-pullover-anthrazit-4be22q04d-q12
#
#                                                media       brand_name  \
# 0  [{'path': 'NI/11/5O/00/MQ/11/NI115O00M-Q11@8.1...  Nike Sportswear
# 1  [{'path': 'NI/11/5O/00/EA/11/NI115O00E-A11@10....  Nike Sportswear
# 2  [{'path': '4B/E2/2Q/04/DK/11/4BE22Q04D-K11@4.j...         Benetton
# 3  [{'path': '4B/E2/2Q/04/DQ/11/4BE22Q04D-Q11@7.j...         Benetton
# 4  [{'path': '4B/E2/2Q/04/DQ/12/4BE22Q04D-Q12@10....         Benetton
#
#    is_premium family_articles  \
# 0       False              []
# 1       False              []
# 2       False              []
# 3       False              []
# 4       False              []
#
#                                                flags product_group  \
# 0  [{'key': 'campaign', 'value': 'HOT DROP', 'tra...          shoe
# 1  [{'key': 'discountRate', 'value': 'Jusqu’à -70...          shoe
# 2  [{'key': 'discountRate', 'value': '-70%', 'tra...      clothing
# 3  [{'key': 'discountRate', 'value': '-70%', 'tra...      clothing
# 4  [{'key': 'discountRate', 'value': '-70%', 'tra...      clothing
#
#   delivery_promises price.original price.promotional  \
# 0                []       104,95 €           31,45 €
# 1                []        99,95 €           29,95 €
# 2                []        39,95 €           11,95 €
# 3                []        39,95 €           11,95 €
# 4                []        39,95 €           11,95 €
#
#    price.has_different_prices  price.has_different_original_prices  \
# 0                        True                                False
# 1                        True                                False
# 2                       False                                False
# 3                       False                                False
# 4                       False                                False
#
#    price.has_different_promotional_prices  \
# 0                                    True
# 1                                    True
# 2                                   False
# 3                                   False
# 4                                   False
#
#    price.has_discount_on_selected_sizes_only outfits
# 0                                      False     NaN
# 1                                      False     NaN
# 2                                      False     NaN
# 3                                      False     NaN
# 4                                      False     NaN

# %%
df = pd.DataFrame()
page_count = results["pagination"]["page_count"]
page_count
# Out:
# 831

# %%
for page in range(page_count):
    url = "https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset"+str(page*84)+"&sort=sale"
    response = requests.get(url, headers=headers)
    results = response.json()
    flattened_data = json_normalize(results)
    flattened_data_art = json_normalize(flattened_data.articles[0])
    art = flattened_data_art.set_index("sku")
    df = df.append(art)

df.head()
# Out:
# C:\Users\Álvaro\anaconda3.1\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
# C:\Users\Álvaro\anaconda3.1\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here
