# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here
from bs4 import BeautifulSoup
import requests
import json
import pandas as pd
from pandas import json_normalize

# %%
#si lo cojo desde firefox:

#url = "https://www.zalando.fr/api/catalog/articles"
#query = {"categories": "promo-homme", "limit": "84", "offset": "84", "sort": "popularity"}
#headers = {"User-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:79.0) Gecko/20100101 Firefox/79.0"}
#response = requests.get(url, params = query, headers = headers)
#json = json.loads(response.text)
#print(json)


#si lo cojo desde chrome:

url3 = "https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset=168&sort=popularity"
headers3 = {"User-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36"}
response3 = requests.get(url, headers = headers)
json3 = json.loads(response.text)
print(json3)

#cada vez que cargo este código tengo que cargar de nuevo los imports o me da error
#he cambiado el número offset de la url y me funciona bien. Me he quedado en la página 3
# Out:
# {'total_count': 69710, 'pagination': {'page_count': 830, 'current_page': 3, 'per_page': 84}, 'sort': 'popularity', 'articles': [{'sku': 'L0642G002-Q12', 'name': 'HERREN SWEATJACKE-SH7609 - veste en sweat zippée - black/pitch chine', 'price': {'original': '109,95\xa0€', 'promotional': '87,95\xa0€', 'has_different_prices': True, 'has_different_original_prices': False, 'has_different_promotional_prices': True, 'has_discount_on_selected_sizes_only': False}, 'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL', '3XL'], 'url_key': 'lacoste-sport-herren-veste-en-sweat-zippee-l0642g002-q12', 'media': [{'path': 'L0/64/2G/00/2Q/12/L0642G002-Q12@9.jpg', 'role': 'DEFAULT', 'packet_shot': False}, {'path': 'L0/64/2G/00/2Q/12/L0642G002-Q12@10.jpg', 'role': 'HOVER', 'packet_shot': False}], 'brand_name': 'Lacoste Sport', 'is_premium': False, 'family_articles': [{'sku': 'L0642G002-Q12', 'url_key': 'lacoste-sport-herren-veste-en-sweat-zippee-l0642g002-q12', 'media': [{'path': 'L0/64/2G/00/2Q/12/L0642G002-Q12@8.jpg', 'role': 'FAMILY', 'packet_shot': True}], 'name': 'HERREN SWEATJACKE-SH7609 - veste en sweat zippée - black/pitch chine', 'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL', '3XL'], 'price': {'original': '109,95\xa0€', 'promotional': '87,95\xa0€', 'has_different_prices': True, 'has_different_original_prices': False, 'has_different_promotional_prices': True, 'has_discount_on_selected_sizes_only': False}, 'flags': [{'key': 'discountRate', 'value': 'Jusqu’à -20%', 'tracking_value': 'discount rate'}], 'delivery_promises': []}, {'sku': 'L0642G002-G14', 'url_key': 'lacoste-sport-herren-veste-en-sweat-zippee-l0642g002-g14', 'media': [{'path': 'L0/64/2G/00/2G/14/L0642G002-G14@7.jpg', 'role': 'FAMILY', 'packet_shot': True}], 'name': 'HERREN SWEATJACKE-SH7609 - veste en sweat zippée - corrida/black', 'sizes': ['L', 'XXL'], 'price': {'original': '109,95\xa0€', 'promotional': '109,95\xa0€', 'has_different_prices': False, 'has_different_original_prices': False, 'has_different_promotional_prices': False, 'has_discount_on_selected_sizes_only': False}, 'flags': [], 'delivery_promises': []}, {'sku': 'L0642G002-C12', 'url_key': 'lacoste-sport-veste-en-sweat-argent-chinemarine-l0642g002-c12', 'media': [{'path': 'L0/64/2G/00/2C/12/L0642G002-C12@12.jpg', 'role': 'FAMILY', 'packet_shot': True}], 'name': 'HERREN SWEATJACKE-SH7609 - veste en sweat zippée - argent chine/marine', 'sizes': ['XS', 'M', 'L', 'XL', 'XXL', '3XL', '4XL', '5XL'], 'price': {'original': '109,95\xa0€', 'promotional': '109,95\xa0€', 'has_different_prices': True, 'has_different_original_prices': True, 'has_different_promotional_prices': False, 'has_discount_on_selected_sizes_only': False}, 'flags': [], 'delivery_promises': []}, {'sku': 'L0642G002-G13', 'url_key': 'lacoste-sport-herren-veste-en-sweat-zippee-l0642g002-g13', 'media': [{'path': 'L0/64/2G/00/2G/13/L0642G002-G13@12.jpg', 'role': 'FAMILY', 'packet_shot': True}], 'name': 'HERREN SWEATJACKE-SH7609 - veste en sweat zippée - red/navy blue', 'sizes': ['XL', 'XXL', '3XL', '4XL'], 'price': {'original': '110,00\xa0€', 'promotional': '110,00\xa0€', 'has_different_prices': False, 'has_different_original_prices': False, 'has_different_promotional_prices': False, 'has_discount_on_selected_sizes_only': False}, 'flags': [{'key': 'campaign', 'value': 'Prix Mini', 'tracking_value': 'fr_prixmini_old_season_2019_28'}], 'delivery_promises': []}, {'sku': 'L0642G002-K12', 'url_key': 'lacoste-sport-sweat-zippe-navy-blue-silver-chine-l0642g002-k12', 'media': [{'path': 'L0/64/2G/00/2K/12/L0642G002-K12@18.jpg', 'role': 'FAMILY', 'packet_shot': True}], 'name': 'HERREN SWEATJACKE-SH7609 - veste en sweat zippée - navy blue/silver chine', 'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL', '3XL', '4XL', '5XL', '6XL'], 'price': {'original': '109,95\xa0€', 'promotional': '87,95\xa0€', 'has_different_prices': True, 'has_different_original_prices': False, 'has_different_promotional_prices': True, 'has_discount_on_selected_sizes_only': False}, 'flags': [{'key': 'discountRate', 'value': ' ...

# %%
dics_json = json3.keys()
print(dics_json)
# Out:
# dict_keys(['total_count', 'pagination', 'sort', 'articles', 'query_path', 'previous_page_path', 'next_page_path', 'query_params', 'page_gender', 'premium', 'filters', 'total_article_count', 'plusStatus', 'categoryTree', 'sortingKeys', 'breadcrumbs', 'querySemantics', 'articlesToShow', 'octopusTests', 'locale', 'isLoggedIn', 'notification', 'resetFilters', 'selectedFilters', 'ssrArticleCount', 'feedbackId', 'variants', 'contentPositions', 'prideEnabled', 'lazyArticleImages', 'hideSearchTerm', 'iconPaths', 'teaser', 'inCatalogTeaser', 'entryPointTeasers', 'upperInCatTeaser', 'collection', 'carouselTeaser', 'wishlist', 'pills', 'sizeOnboardingDialog'])

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
from bs4 import BeautifulSoup
import requests
import json
import pandas as pd
from pandas import json_normalize

# %%
#Aquí está el contenido de la primera página
url = "https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset=0&sort=popularity"
headers = {"User-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36"}
response = requests.get(url, headers = headers)
json = json.loads(response.text)
print(json)
# Out:
# {'total_count': 69701, 'pagination': {'page_count': 830, 'current_page': 1, 'per_page': 84}, 'sort': 'popularity', 'articles': [{'sku': 'PU142D0WW-A11', 'name': 'HOOPS PULL UP TEE - T-shirt à manches longues - white', 'price': {'original': '33,95\xa0€', 'promotional': '10,15\xa0€', 'has_different_prices': True, 'has_different_original_prices': False, 'has_different_promotional_prices': True, 'has_discount_on_selected_sizes_only': False}, 'sizes': ['S', 'M', 'L', 'XL', 'XXL'], 'url_key': 'puma-hoops-pull-up-tee-t-shirt-a-manches-longues-white-pu142d0ww-a11', 'media': [{'path': 'PU/14/2D/0W/WA/11/PU142D0WW-A11@8.jpg', 'role': 'DEFAULT', 'packet_shot': False}, {'path': 'PU/14/2D/0W/WA/11/PU142D0WW-A11@7.jpg', 'role': 'HOVER', 'packet_shot': False}], 'brand_name': 'Puma', 'is_premium': False, 'family_articles': [], 'flags': [{'key': 'discountRate', 'value': 'Jusqu’à -70%', 'tracking_value': 'discount rate'}, {'key': 'sponsored', 'value': 'Sponsorisé', 'tracking_value': 'sponsored'}], 'tracking_information': {'metrigo_impression_urls': ['https://ccp-et.adtechlab.zalan.do/event/sbv?z=f4cf94d6-112e-4492-bd22-08cfac86be34&b=a5dd3a9a-9ea9-474d-bfbf-45aaa53437c3:30047813:PU142D0WW-A11&c=30047813&a=30047818&s=PU142D0WW-A11&is=1689&at=browser&cm=110000&ovm=1014&r=0.00936866644769907&ts=0&cs=1036327088'], 'impression_beacon': 'https://ccp-et.adtechlab.zalan.do/event/sbv?z=f4cf94d6-112e-4492-bd22-08cfac86be34&b=a5dd3a9a-9ea9-474d-bfbf-45aaa53437c3:30047813:PU142D0WW-A11&c=30047813&a=30047818&s=PU142D0WW-A11&is=1689&at=browser&cm=110000&ovm=1014&r=0.00936866644769907&ts=0&cs=1036327088', 'source': 'ccp'}, 'product_group': 'clothing', 'delivery_promises': []}, {'sku': 'TI112D04Z-B11', 'name': 'KILLINGTON CHUKKA - Bottines à lacets - wheat', 'price': {'original': '139,95\xa0€', 'promotional': '69,95\xa0€', 'has_different_prices': False, 'has_different_original_prices': False, 'has_different_promotional_prices': False, 'has_discount_on_selected_sizes_only': False}, 'sizes': ['40', '42', '43', '43.5', '44.5', '45', '45.5', '46', '47.5', '49', '50'], 'url_key': 'timberland-killington-bottines-a-lacets-wheat-ti112d04z-b11', 'media': [{'path': 'TI/11/2D/04/ZB/11/TI112D04Z-B11@12.2.jpg', 'role': 'DEFAULT', 'packet_shot': True}, {'path': 'TI/11/2D/04/ZB/11/TI112D04Z-B11@13.1.jpg', 'role': 'HOVER', 'packet_shot': False}], 'brand_name': 'Timberland', 'is_premium': False, 'family_articles': [], 'flags': [{'key': 'discountRate', 'value': '-50%', 'tracking_value': 'discount rate'}, {'key': 'sponsored', 'value': 'Sponsorisé', 'tracking_value': 'sponsored'}, {'key': 'csr', 'value': 'Éco-responsabilité', 'tracking_value': 'sustainable'}], 'tracking_information': {'metrigo_impression_urls': ['https://ccp-et.adtechlab.zalan.do/event/sbv?z=f4cf94d6-112e-4492-bd22-08cfac86be34&b=a5dd3a9a-9ea9-474d-bfbf-45aaa53437c3:30047217:TI112D04Z-B11&c=30047217&a=30047226&s=TI112D04Z-B11&is=1689&at=browser&cm=180000&ovm=749&r=0.005634693428874016&ts=0&cs=2123105949'], 'impression_beacon': 'https://ccp-et.adtechlab.zalan.do/event/sbv?z=f4cf94d6-112e-4492-bd22-08cfac86be34&b=a5dd3a9a-9ea9-474d-bfbf-45aaa53437c3:30047217:TI112D04Z-B11&c=30047217&a=30047226&s=TI112D04Z-B11&is=1689&at=browser&cm=180000&ovm=749&r=0.005634693428874016&ts=0&cs=2123105949', 'source': 'ccp'}, 'product_group': 'shoe', 'delivery_promises': []}, {'sku': 'TI112O01U-Q11', 'name': 'KILLINGTON - Baskets basses - black', 'price': {'original': '109,95\xa0€', 'promotional': '59,95\xa0€', 'has_different_prices': True, 'has_different_original_prices': False, 'has_different_promotional_prices': True, 'has_discount_on_selected_sizes_only': False}, 'sizes': ['40', '41.5', '43.5', '44', '45', '45.5', '46', '47.5'], 'url_key': 'timberland-killington-baskets-basses-black-ti112o01u-q11', 'media': [{'path': 'TI/11/2O/01/UQ/11/TI112O01U-Q11@9.jpg', 'role': 'DEFAULT', 'packet_shot': True}], 'brand_name': 'Timberland', 'is_premium': False, 'family_articles': [], 'flags': [{'key': 'discountRate', 'value': 'Jusqu’à -45%', 'tr ...

# %%
#vamos a ver los diccionarios de primera línea
dics_json = json.keys()
print(dics_json)
# Out:
# dict_keys(['total_count', 'pagination', 'sort', 'articles', 'query_path', 'next_page_path', 'query_params', 'page_gender', 'premium', 'filters', 'total_article_count', 'plusStatus', 'categoryTree', 'sortingKeys', 'breadcrumbs', 'querySemantics', 'articlesToShow', 'octopusTests', 'locale', 'isLoggedIn', 'notification', 'resetFilters', 'selectedFilters', 'ssrArticleCount', 'feedbackId', 'variants', 'contentPositions', 'prideEnabled', 'lazyArticleImages', 'hideSearchTerm', 'iconPaths', 'teaser', 'inCatalogTeaser', 'entryPointTeasers', 'upperInCatTeaser', 'collection', 'carouselTeaser', 'wishlist', 'pills', 'sizeOnboardingDialog'])

# %%
from pandas import json_normalize

# %%
flattened_json = pd.json_normalize(json)
flattened_json
# Out:
#    total_count        sort                                           articles  \
# 0        69701  popularity  [{'sku': 'PU142D0WW-A11', 'name': 'HOOPS PULL ...
#
#       query_path     next_page_path page_gender  premium  \
# 0  /promo-homme/  /promo-homme/?p=2         men    False
#
#                                              filters  total_article_count  \
# 0  [{'key': 'sizes', 'label': 'Taille', 'url_key'...                69704
#
#      plusStatus  ... teaser.content.tracking_data.cf_tracking_params.slot_id  \
# 0  non-eligible  ...               21672e65-4b93-4cd0-9943-404c19eece9a
#
#   teaser.content.tracking_data.cf_tracking_params.flow_id  \
# 0                                   P8xlvCkpExcW50Ut
#
#   teaser.content.tracking_data.cf_tracking_params.shop_slot_id  \
# 0                                            catalog
#
#    teaser.content.tracking_data.cf_tracking_params.campaign_source_id  \
# 0                                        K6h64IsdQ6q
#
#   teaser.content.tracking_data.cf_tracking_params.request_id  \
# 0               a8cd8a47-b991-4799-9e3d-5cad5058e725
#
#   teaser.content.tracking_data.cf_tracking_params.campaign_id  \
# 0               23b73eb6-7923-421f-a54d-5abd95a88e36
#
#    teaser.content.tracking_data.cf_tracking_params.creative_id  \
# 0               64ac1450-b7b5-4f4b-8319-ed19fe1a50c7
#
#                         teaser.content.click_url  teaser.channel_name  \
# 0  https://www.zalando.fr/promo-homme/&Sale=True                   CF
#
#                          teaser.slot_id
# 0  21672e65-4b93-4cd0-9943-404c19eece9a
#
# [1 rows x 176 columns]

# %%
#no entiendo por qué en el df no me aparece el pagination, ha desaparecido!

# %%
flattened_json.columns
# Out:
# Index(['total_count', 'sort', 'articles', 'query_path', 'next_page_path',
#        'page_gender', 'premium', 'filters', 'total_article_count',
#        'plusStatus',
#        ...
#        'teaser.content.tracking_data.cf_tracking_params.slot_id',
#        'teaser.content.tracking_data.cf_tracking_params.flow_id',
#        'teaser.content.tracking_data.cf_tracking_params.shop_slot_id',
#        'teaser.content.tracking_data.cf_tracking_params.campaign_source_id',
#        'teaser.content.tracking_data.cf_tracking_params.request_id',
#        'teaser.content.tracking_data.cf_tracking_params.campaign_id',
#        'teaser.content.tracking_data.cf_tracking_params.creative_id',
#        'teaser.content.click_url', 'teaser.channel_name', 'teaser.slot_id'],
#       dtype='object', length=176)

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
#entiendo que aquí quiere hacer un flatten solamente del diccionario articles, no de todo
articulos = json.get("articles") 
print(articulos)
# Out:
# [{'sku': 'PU142D0WW-A11', 'name': 'HOOPS PULL UP TEE - T-shirt à manches longues - white', 'price': {'original': '33,95\xa0€', 'promotional': '10,15\xa0€', 'has_different_prices': True, 'has_different_original_prices': False, 'has_different_promotional_prices': True, 'has_discount_on_selected_sizes_only': False}, 'sizes': ['S', 'M', 'L', 'XL', 'XXL'], 'url_key': 'puma-hoops-pull-up-tee-t-shirt-a-manches-longues-white-pu142d0ww-a11', 'media': [{'path': 'PU/14/2D/0W/WA/11/PU142D0WW-A11@8.jpg', 'role': 'DEFAULT', 'packet_shot': False}, {'path': 'PU/14/2D/0W/WA/11/PU142D0WW-A11@7.jpg', 'role': 'HOVER', 'packet_shot': False}], 'brand_name': 'Puma', 'is_premium': False, 'family_articles': [], 'flags': [{'key': 'discountRate', 'value': 'Jusqu’à -70%', 'tracking_value': 'discount rate'}, {'key': 'sponsored', 'value': 'Sponsorisé', 'tracking_value': 'sponsored'}], 'tracking_information': {'metrigo_impression_urls': ['https://ccp-et.adtechlab.zalan.do/event/sbv?z=44a397fd-c585-4846-afcd-8120554b7585&b=8ea8250b-e009-4ee7-ae7a-393fc390fd35:30047813:PU142D0WW-A11&c=30047813&a=30047818&s=PU142D0WW-A11&is=1689&at=browser&cm=110000&ovm=1014&r=0.00936866644769907&ts=0&cs=4039791432'], 'impression_beacon': 'https://ccp-et.adtechlab.zalan.do/event/sbv?z=44a397fd-c585-4846-afcd-8120554b7585&b=8ea8250b-e009-4ee7-ae7a-393fc390fd35:30047813:PU142D0WW-A11&c=30047813&a=30047818&s=PU142D0WW-A11&is=1689&at=browser&cm=110000&ovm=1014&r=0.00936866644769907&ts=0&cs=4039791432', 'source': 'ccp'}, 'product_group': 'clothing', 'delivery_promises': []}, {'sku': 'TI112D04Z-B11', 'name': 'KILLINGTON CHUKKA - Bottines à lacets - wheat', 'price': {'original': '139,95\xa0€', 'promotional': '69,95\xa0€', 'has_different_prices': False, 'has_different_original_prices': False, 'has_different_promotional_prices': False, 'has_discount_on_selected_sizes_only': False}, 'sizes': ['40', '42', '43', '43.5', '44.5', '45', '45.5', '46', '47.5', '49', '50'], 'url_key': 'timberland-killington-bottines-a-lacets-wheat-ti112d04z-b11', 'media': [{'path': 'TI/11/2D/04/ZB/11/TI112D04Z-B11@12.2.jpg', 'role': 'DEFAULT', 'packet_shot': True}, {'path': 'TI/11/2D/04/ZB/11/TI112D04Z-B11@13.1.jpg', 'role': 'HOVER', 'packet_shot': False}], 'brand_name': 'Timberland', 'is_premium': False, 'family_articles': [], 'flags': [{'key': 'discountRate', 'value': '-50%', 'tracking_value': 'discount rate'}, {'key': 'sponsored', 'value': 'Sponsorisé', 'tracking_value': 'sponsored'}, {'key': 'csr', 'value': 'Éco-responsabilité', 'tracking_value': 'sustainable'}], 'tracking_information': {'metrigo_impression_urls': ['https://ccp-et.adtechlab.zalan.do/event/sbv?z=44a397fd-c585-4846-afcd-8120554b7585&b=8ea8250b-e009-4ee7-ae7a-393fc390fd35:30047217:TI112D04Z-B11&c=30047217&a=30047226&s=TI112D04Z-B11&is=1689&at=browser&cm=180000&ovm=749&r=0.005634693428874016&ts=0&cs=3441914872'], 'impression_beacon': 'https://ccp-et.adtechlab.zalan.do/event/sbv?z=44a397fd-c585-4846-afcd-8120554b7585&b=8ea8250b-e009-4ee7-ae7a-393fc390fd35:30047217:TI112D04Z-B11&c=30047217&a=30047226&s=TI112D04Z-B11&is=1689&at=browser&cm=180000&ovm=749&r=0.005634693428874016&ts=0&cs=3441914872', 'source': 'ccp'}, 'product_group': 'shoe', 'delivery_promises': []}, {'sku': 'TI112O01U-Q11', 'name': 'KILLINGTON - Baskets basses - black', 'price': {'original': '109,95\xa0€', 'promotional': '59,95\xa0€', 'has_different_prices': True, 'has_different_original_prices': False, 'has_different_promotional_prices': True, 'has_discount_on_selected_sizes_only': False}, 'sizes': ['40', '41.5', '43.5', '44', '45', '45.5', '46', '47.5'], 'url_key': 'timberland-killington-baskets-basses-black-ti112o01u-q11', 'media': [{'path': 'TI/11/2O/01/UQ/11/TI112O01U-Q11@9.jpg', 'role': 'DEFAULT', 'packet_shot': True}], 'brand_name': 'Timberland', 'is_premium': False, 'family_articles': [], 'flags': [{'key': 'discountRate', 'value': 'Jusqu’à -45%', 'tracking_value': 'discount rate'}, {'key': 'sponsored', 'value': 'Sponsorisé', 'tracking_value': 'sponsored'}, {'key': 'csr', 'va ...

# %%
flattened_articulos = pd.json_normalize(articulos)
flattened_articulos
# Out:
#               sku                                               name  \
# 0   PU142D0WW-A11  HOOPS PULL UP TEE - T-shirt à manches longues ...
# 1   TI112D04Z-B11      KILLINGTON CHUKKA - Bottines à lacets - wheat
# 2   TI112O01U-Q11                KILLINGTON - Baskets basses - black
# 3   TOB22O018-A11  ORIGINAL TEE REGULAR FIT - T-shirt basique - c...
# 4   LA222S02S-B11                               Pullover - viennesse
# ..            ...                                                ...
# 79  L0642D003-A11                                       Polo - blanc
# 80  TO152F043-Q11                        ETON - Portefeuille - black
# 81  LA242L002-G11                              Sac à dos - tango red
# 82  IJ022F00I-B12                           CASUAL FIT - Short - fog
# 83  PO254Q002-C11                           Casquette - perfect grey
#
#                                                 sizes  \
# 0                                  [S, M, L, XL, XXL]
# 1   [40, 42, 43, 43.5, 44.5, 45, 45.5, 46, 47.5, 4...
# 2            [40, 41.5, 43.5, 44, 45, 45.5, 46, 47.5]
# 3                              [XS, S, M, L, XL, XXL]
# 4                    [XS, S, M, L, XL, XXL, 3XL, 4XL]
# ..                                                ...
# 79                            [S, M, L, XL, XXL, 3XL]
# 80                                         [One Size]
# 81                                         [One Size]
# 82                            [S, M, L, XL, XXL, 3XL]
# 83                                         [One Size]
#
#                                               url_key  \
# 0   puma-hoops-pull-up-tee-t-shirt-a-manches-longu...
# 1   timberland-killington-bottines-a-lacets-wheat-...
# 2   timberland-killington-baskets-basses-black-ti1...
# 3   tommy-jeans-original-tee-regular-fit-t-shirt-b...
# 4            lacoste-pullover-viennesse-la222s02s-b11
# ..                                                ...
# 79             lacoste-sport-polo-blanc-l0642d003-a11
# 80     tommy-hilfiger-eton-portefeuille-to152f043-q11
# 81          lacoste-sac-a-dos-tango-red-la242l002-g11
# 82    indicode-jeans-70-039s-cuba-short-ij022f00i-b12
# 83  polo-ralph-lauren-casquette-perfect-grey-po254...
#
#                                                 media         brand_name  \
# 0   [{'path': 'PU/14/2D/0W/WA/11/PU142D0WW-A11@8.j...               Puma
# 1   [{'path': 'TI/11/2D/04/ZB/11/TI112D04Z-B11@12....         Timberland
# 2   [{'path': 'TI/11/2O/01/UQ/11/TI112O01U-Q11@9.j...         Timberland
# 3   [{'path': 'TO/B2/2O/01/8A/11/TOB22O018-A11@8.j...        Tommy Jeans
# 4   [{'path': 'LA/22/2S/02/SB/11/LA222S02S-B11@13....            Lacoste
# ..                                                ...                ...
# 79  [{'path': 'L0/64/2D/00/3A/11/L0642D003-A11@15....      Lacoste Sport
# 80  [{'path': 'TO/15/2F/04/3Q/11/TO152F043-Q11@2.j...     Tommy Hilfiger
# 81  [{'path': 'LA/24/2L/00/2G/11/LA242L002-G11@5.j...            Lacoste
# 82  [{'path': 'IJ/02/2F/00/IB/12/IJ022F00I-B12@42....     INDICODE JEANS
# 83  [{'path': 'PO/25/4Q/00/2C/11/PO254Q002-C11@10....  Polo Ralph Lauren
#
#     is_premium family_articles  \
# 0        False              []
# 1        False              []
# 2        False              []
# 3        False              []
# 4        False              []
# ..         ...             ...
# 79       False              []
# 80       False              []
# 81       False              []
# 82       False              []
# 83       False              []
#
#                                                 flags product_group  \
# 0   [{'key': 'discountRate', 'value': 'Jusqu’à -70...      clothing
# 1   [{'key': 'discountRate', 'value': '-50%', 'tra...          shoe
# 2   [{'key': 'discountRate', 'value': 'Jusqu’à -45...          shoe
# 3   [{'key': 'discountRate', 'value': '-10%', 'tra...      clothing
# 4   [{'key': 'discountRate', 'value': '-50%', 'tra...      clothing
# ..                                                ...           ...
# 79  [{'key': 'discountRate', 'value': 'Jusqu’à -15...      clothing
# 80  [{'key': 'discountRate', 'value': '-25%', 'tra...   accessoires
# 81  [{'key': 'discountRate', 'value': '-40%', 'tra...   accessoires
# 82  [{'key': 'discountRate', 'value': '-8%', 'trac...      clothing
# 83  [{'key': 'discountRate', 'value': '-45%', 'tra...   accessoires
#
#    delivery_promises price.original price.promotional  \
# 0                 []        33,95 €           10,15 €
# 1                 []       139,95 €           69,95 €
# 2                 []       109,95 €           59,95 €
# 3                 []        23,95 €           21,55 €
# 4                 []       119,95 €           59,95 €
# ..               ...            ...               ...
# 79                []        69,95 €           59,45 €
# 80                []        64,95 €           48,45 €
# 81                []        85,00 €           51,00 €
# 82                []        39,95 €           36,95 €
# 83                []        49,95 €           27,65 €
#
#     price.has_different_prices  price.has_different_original_prices  \
# 0                         True                                False
# 1                        False                                False
# 2                         True                                False
# 3                        False                                False
# 4                        False                                False
# ..                         ...                                  ...
# 79                        True                                False
# 80                       False                                False
# 81                       False                                False
# 82                       False                                False
# 83                       False                                False
#
#     price.has_different_promotional_prices  \
# 0                                     True
# 1                                    False
# 2                                     True
# 3                                    False
# 4                                    False
# ..                                     ...
# 79                                    True
# 80                                   False
# 81                                   False
# 82                                   False
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ..                                        ...
# 79                                      False
# 80                                      False
# 81                                      False
# 82                                      False
# 83                                      False
#
#          tracking_information.metrigo_impression_urls  \
# 0   [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# 1   [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# 2   [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
#
#                tracking_information.impression_beacon  \
# 0   https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# 1   https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# 2   https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
#
#    tracking_information.source
# 0                          ccp
# 1                          ccp
# 2                          ccp
# 3                          NaN
# 4                          NaN
# ..                         ...
# 79                         NaN
# 80                         NaN
# 81                         NaN
# 82                         NaN
# 83                         NaN
#
# [84 rows x 20 columns]
