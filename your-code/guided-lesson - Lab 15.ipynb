# %% [markdown]
# # Parsing APIs Example

# %% [markdown]
# ## Intro
#
# Now we will take a look on a real data. When you parse data from web you will often meet API based web-pages.
#
# For example [zalando.fr](https://www.zalando.fr/accueil-homme/) is API based web-page.
#
# In this guided lab you will learn how to obtain the links from webpages and extract the data. Read through this doc, execute the cells in order and make sure you understand the explanations.
#
# *Note: This guided lab uses Google Chrome. Other browsers like Safari and Firefox have similar tools for developers but they work differently. To save your time in following this lab, it is strongly recommended that you install and use Google Chrome.*

# %% [markdown]
# ## Obtaining the link
#
# Zalando is discount e-store where you can buy clothes and accesories with discount. When we go to the web-page, we can choose different sections. First the general process will be shown using [Children section](https://www.zalando.fr/accueil-enfant/) as example.
#
# Here we will parse data about promotions only. Therefore, final output will be the DataFrame with all the goods under discount.
#
# [![Image from Gyazo](https://i.gyazo.com/fa4874d8e81c7570273bbfb853d66308.png)](https://gyazo.com/fa4874d8e81c7570273bbfb853d66308)
#
#
# We go to Promos page. Right click of mouse shows us a list of actions possible, from which we select Inspect.
#
# <img src='https://i.gyazo.com/bccbd11d69c9040dc98758d443e32052.png' width="400">
#
#
# You will see the menu dropdown on the right side or on the bottom of the window. There you should click on Network:
#
#
# [![Image from Gyazo](https://i.gyazo.com/f7e0db81cbfee67694183d1a7640bf81.png)](https://gyazo.com/f7e0db81cbfee67694183d1a7640bf81)

# %% [markdown]
# Right after the developer part will change showing the files behind the page. In order to obtain only useful files we select the following settings:
# 1. Preserve Log
# 2. Select XHR files.
#
# [![Image from Gyazo](https://i.gyazo.com/9a899d4441d9d93e795f79747f1e47d5.png)](https://gyazo.com/9a899d4441d9d93e795f79747f1e47d5)
#
# In order to obtain some files we need to scrool down and go forward to second page.
#
# [![Image from Gyazo](https://i.gyazo.com/0956eb3d5125075a236c9a439c7749c7.png)](https://gyazo.com/0956eb3d5125075a236c9a439c7749c7)
#
# In the Network panel you can see the following files being uploaded. All the data on the web-page is uploaded from the json file, which is one of the following. It is important to understand which file contains what kind of information.
#
# <a href="https://gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c"><img src="https://i.gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c.png" alt="Image from Gyazo" width="724.8"/></a>
#
# When you find what kind of information you need for the data to be uploaded you just test it. Here we need the article... file:
#
# <a href="https://gyazo.com/78b35bf492994b3f35c0564a21da202a"><img src="https://i.gyazo.com/78b35bf492994b3f35c0564a21da202a.png" alt="Image from Gyazo" width="727.2"/></a>
#
# When we test the link in Chrome inkognito mode we obtain the proper json file:
#
#
# <a href="https://gyazo.com/b60453fa98454fa29771c731a5174443"><img src="https://i.gyazo.com/b60453fa98454fa29771c731a5174443.png" alt="Image from Gyazo" width="1530.4"/></a>

# %% [markdown]
# In order to change the objects in the json file (kind of pagination), you need to change the offset (the number of the first element on the page). in fact, if you take a look on the link, it is easy to unerstand the structure of the link.
#
# # Reading the data
#
# Now the party rocks! When we know how can we obtain the data, it is not a problem to obtain the whole database with all the data from the web-page.
# In this lab you will collect your database of Zalando products. You select which goods you want to track. You can define as many filters to your data as you want. Just make sure that the data represents the filters.

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
# Paste the url you obtained for your data
#url='https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=84&sort=sale'

# a mí me lo ha dado ordenador por popularidad
url = "https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=84&sort=popularity"

# %% [markdown]
# #### Collect first 84 object of the of the data (1st page)
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having *family_articles, flags, media* and *sizes* remaining lists (they are exceptions). Hint: use the headers parameter to get the data!

# %%
# headers definition (cogido de los apuntes del notebook Api exchange)

headers = {"User-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36"}

# cogido de cómo trabamajos el diccionario de las exchange rates, notebook Api exchange)
response = requests.get(url, headers = headers)
goods = json.loads(response.text)
print(goods)
# Out:
# {'total_count': 27584, 'pagination': {'page_count': 329, 'current_page': 2, 'per_page': 84}, 'sort': 'popularity', 'articles': [{'sku': 'NI126B00W-Q11', 'name': 'HYBRID PANT - Pantalon de survêtement - black', 'price': {'original': '44,95\xa0€', 'promotional': '26,95\xa0€', 'has_different_prices': False, 'has_different_original_prices': False, 'has_different_promotional_prices': False, 'has_discount_on_selected_sizes_only': False}, 'sizes': ['6-7a', '8-9a', '10-11a'], 'url_key': 'nike-sportswear-hybrid-pantalon-de-survetement-black-ni126b00w-q11', 'media': [{'path': 'NI/12/6B/00/WQ/11/NI126B00W-Q11@8.1.jpg', 'role': 'DEFAULT', 'packet_shot': False}], 'brand_name': 'Nike Sportswear', 'is_premium': False, 'family_articles': [{'sku': 'NI126B00W-Q11', 'url_key': 'nike-sportswear-hybrid-pantalon-de-survetement-black-ni126b00w-q11', 'media': [{'path': 'NI/12/6B/00/WQ/11/NI126B00W-Q11@8.1.jpg', 'role': 'FAMILY', 'packet_shot': False}], 'name': 'HYBRID PANT - Pantalon de survêtement - black', 'sizes': ['6-7a', '8-9a', '10-11a'], 'price': {'original': '44,95\xa0€', 'promotional': '26,95\xa0€', 'has_different_prices': False, 'has_different_original_prices': False, 'has_different_promotional_prices': False, 'has_discount_on_selected_sizes_only': False}, 'flags': [{'key': 'discountRate', 'value': '-40%', 'tracking_value': 'discount rate'}], 'delivery_promises': []}, {'sku': 'NI126B00W-C11', 'url_key': 'nike-sportswear-hybrid-pantalon-de-survetement-ni126b00w-c11', 'media': [{'path': 'NI/12/6B/00/WC/11/NI126B00W-C11@8.1.jpg', 'role': 'FAMILY', 'packet_shot': False}], 'name': 'HYBRID PANT - Pantalon de survêtement - grey heather/midnight navy/white', 'sizes': ['8-9a', '10-11a', '12-13a'], 'price': {'original': '43,95\xa0€', 'promotional': '30,75\xa0€', 'has_different_prices': False, 'has_different_original_prices': False, 'has_different_promotional_prices': False, 'has_discount_on_selected_sizes_only': False}, 'flags': [{'key': 'discountRate', 'value': '-30%', 'tracking_value': 'discount rate'}], 'delivery_promises': []}, {'sku': 'NI126B00W-I11', 'url_key': 'nike-sportswear-hybrid-pantalon-de-survetement-ni126b00w-i11', 'media': [{'path': 'NI/12/6B/00/WI/11/NI126B00W-I11@2.jpg', 'role': 'FAMILY', 'packet_shot': False}], 'name': 'HYBRID PANT - Pantalon de survêtement - charcoal heather/black', 'sizes': ['8-9a', '10-11a', '12-13a', '14a'], 'price': {'original': '44,95\xa0€', 'promotional': '44,95\xa0€', 'has_different_prices': False, 'has_different_original_prices': False, 'has_different_promotional_prices': False, 'has_discount_on_selected_sizes_only': False}, 'flags': [], 'delivery_promises': []}, {'sku': 'NI126B00W-C12', 'url_key': 'nike-sportswear-hybrid-pantalon-de-survetement-ni126b00w-c12', 'media': [{'path': 'NI/12/6B/00/WC/12/NI126B00W-C12@8.jpg', 'role': 'FAMILY', 'packet_shot': False}], 'name': 'HYBRID PANT - Pantalon de survêtement - obsidian mist/football grey/track red', 'sizes': ['8-9a', '10-11a', '12-13a', '14a'], 'price': {'original': '44,95\xa0€', 'promotional': '33,65\xa0€', 'has_different_prices': False, 'has_different_original_prices': False, 'has_different_promotional_prices': False, 'has_discount_on_selected_sizes_only': False}, 'flags': [{'key': 'discountRate', 'value': '-25%', 'tracking_value': 'discount rate'}], 'delivery_promises': []}], 'flags': [{'key': 'discountRate', 'value': '-40%', 'tracking_value': 'discount rate'}], 'product_group': 'clothing', 'delivery_promises': []}, {'sku': 'HG223F0C3-J11', 'name': 'Robe de soirée - lila', 'price': {'original': '34,95\xa0€', 'promotional': '13,95\xa0€', 'has_different_prices': False, 'has_different_original_prices': False, 'has_different_promotional_prices': False, 'has_discount_on_selected_sizes_only': False}, 'sizes': ['3-4a', '5-6a', '7-8a', '9-10a', '11-12a', '13-14a', '15-16a'], 'url_key': 'happy-girls-robe-de-soiree-lila-hg223f0c3-j11', 'media': [{'path': 'HG/22/3F/0C/3J/11/HG223F0C3-J11@6.jpg', 'role': 'DEFAULT', 'packet_shot': False}], 'brand_name': 'happy girls' ...

# %%
import pandas as pd

# %%
# Your code
pd.DataFrame(response.json())

#Entiendo que flatten la columna del df, cierto?
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-9c59b9a449a4> in <module>
#       1 # Your code
# ----> 2 pd.DataFrame(response.json())
#       3
#       4 #no me queda claro si esto es correcto. Entiendo que no, pero para ello tengo que flatten la columna del df?
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      62     # figure out the index, if necessary
#      63     if index is None:
# ---> 64         index = extract_index(arrays)
#      65     else:
#      66         index = ensure_index(index)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     363             lengths = list(set(raw_lengths))
#     364             if len(lengths) > 1:
# --> 365                 raise ValueError("arrays must all be same length")
#     366
#     367             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
from pandas.io.json import json_normalize

# %%
#por lo que he visto en los apuntes, hay que hacer un flatten del diccionario para que te lo desanide:

results = response.json()
flattened_data = json_normalize(results)

flattened_data.head()
# Out:
# /Users/blancurri/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   after removing the cwd from sys.path.
#    total_count        sort                                           articles  \
# 0        27584  popularity  [{'sku': 'NI126B00W-Q11', 'name': 'HYBRID PANT...
#
#            query_path previous_page_path      next_page_path page_gender  \
# 0  /promo-enfant/?p=2     /promo-enfant/  /promo-enfant/?p=3        kids
#
#    premium                                            filters  \
# 0    False  [{'key': 'sizes', 'label': 'Taille', 'url_key'...
#
#    total_article_count  ...  \
# 0                27584  ...
#
#   teaser.content.tracking_data.cf_tracking_params.slot_id  \
# 0               21672e65-4b93-4cd0-9943-404c19eece9a
#
#   teaser.content.tracking_data.cf_tracking_params.flow_id  \
# 0                                   NoJjSWfbz550IVNV
#
#   teaser.content.tracking_data.cf_tracking_params.shop_slot_id  \
# 0                                            catalog
#
#   teaser.content.tracking_data.cf_tracking_params.campaign_source_id  \
# 0                                        ahmlXDDsS9q
#
#    teaser.content.tracking_data.cf_tracking_params.request_id  \
# 0               cd4da1a2-f5e7-4ec7-a526-db33a9966bc7
#
#   teaser.content.tracking_data.cf_tracking_params.campaign_id  \
# 0               7385762b-6777-4b4f-8f67-d62b19ad806e
#
#   teaser.content.tracking_data.cf_tracking_params.creative_id  \
# 0               38cf37d5-e629-4fb8-90e3-e616ef6838dd
#
#                          teaser.content.click_url teaser.channel_name  \
# 0  https://www.zalando.fr/promo-enfant/&Sale=True                  CF
#
#                          teaser.slot_id
# 0  21672e65-4b93-4cd0-9943-404c19eece9a
#
# [1 rows x 177 columns]

# %%
#cojo solo el contenido de la columna artículos
flattened_data["articles"]
# Out:
# 0    [{'sku': 'NI126B00W-Q11', 'name': 'HYBRID PANT...
# Name: articles, dtype: object

# %%
#pero ahora me lo mete todo en una sola fila

# %%
#Creo que tengo que partir del response como un json, no como text

#response_json = response.json()

# %%
#y repetiremos ahora el df des del json:
#zal_de_json = pd.DataFrame(response_json)

#zal_de_json.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-9cce1a2edebb> in <module>
#       1 #y repetiremos ahora el df des del json:
# ----> 2 zal_de_json = pd.DataFrame(response_json)
#       3
#       4 zal_de_json.head()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      62     # figure out the index, if necessary
#      63     if index is None:
# ---> 64         index = extract_index(arrays)
#      65     else:
#      66         index = ensure_index(index)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     363             lengths = list(set(raw_lengths))
#     364             if len(lengths) > 1:
# --> 365                 raise ValueError("arrays must all be same length")
#     366
#     367             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
type(response)
# Out:
# requests.models.Response

# %%
type(zal)
# Out:
# pandas.core.frame.DataFrame

# %%
from pandas.io.json import json_normalize
results = response.json()
flattened_data = json_normalize(results)
flattened_data

# %% [markdown]
# #### Collect all the objects from selected filters. Total number of pages can be found in the same json. Use *sku* column as index.
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having family_articles, flags, media and sizes remaining lists (they are exceptions).

# %%
# Get the total number of pages


# Your code

# %% [markdown]
# #### Display the trending brand in DataFrame

# %%
# your code

# %% [markdown]
# #### Display the brand with maximal total discount (sum of discounts on all goods)

# %%
#Our data is still text. Convert prices into numbers.
# your code

# %% [markdown]
# #### Display the brands without discount at all

# %%
# your code
